# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import time
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# %% [markdown]
# # K-DRONE Optimization Pipeline
#
# ## Workflow:
# 1. **Data Loading** → Load titik_semprotan.csv, build distance matrix
# 2. **Clustering** → K-Means untuk bagi nodes ke K vehicles/zones
# 3. **Optimization** → 2-OPT, Lovebird GA, atau ILS untuk optimize per-cluster routes
# 4. **Visualization** → Plot clusters, routes, convergence history
#
# ## Helper Functions:
# - `total_distance(tour)` - Hitung total jarak satu rute (circular)
# - `plot_clusters()` - Visualisasi hasil K-Means
# - `elbow_analysis()` - Tentukan K optimal
# - `run_kmeans()` - Jalankan K-Means clustering

# %%
# === DATA LOADING & INITIALIZATION ===
# Load data dari CSV
df = pd.read_csv('titik_semprotan.csv')
ids = df['id'].tolist()
locations = df[['x', 'y']].values

# Build mappings untuk efficient lookup
id2idx = {i: k for k, i in enumerate(ids)}              # id -> index in locations
nodes = list(dict.fromkeys(ids))                        # unique IDs, order-preserving
idx = {node: k for k, node in enumerate(nodes)}         # node ID -> index in nodes

# === DISTANCE MATRIX (Vectorized) ===
# Bangun koordinat matrix sesuai urutan nodes
N = len(nodes)
coords = np.empty((N, 2), dtype=np.float64)
for k, node in enumerate(nodes):
    orig_idx = id2idx[node]
    coords[k] = locations[orig_idx]

# Hitung distance matrix sekali (O(N²), tapi bisa dipakai berkali-kali)
diff = coords[:, None, :] - coords[None, :, :]  # vectorized difference
D = np.sqrt((diff * diff).sum(axis=2))           # Euclidean distance
np.fill_diagonal(D, 0.0)                         # diagonal = 0

print(f"Data loaded: {N} points, distance matrix shape {D.shape}")

# === HELPER FUNCTIONS ===
def total_distance(tour):
    """Hitung total jarak satu tour (termasuk kembali ke awal)"""
    L = len(tour)
    if L < 2:
        return 0.0
    
    distance = sum(D[idx[tour[i]], idx[tour[i+1]]] for i in range(L - 1))
    distance += D[idx[tour[-1]], idx[tour[0]]]  # kembali ke awal
    return float(distance)

def split_ids(ids_list, num_vehicles):
    """Bagi IDs ke num_vehicles rute secara acak"""
    shuffled = ids_list[:]
    random.shuffle(shuffled)
    return [shuffled[i::num_vehicles] for i in range(num_vehicles)]
# Out:
# Data loaded: 135 points, distance matrix shape (135, 135)

# %% [markdown]
# # K Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

def elbow_analysis(coords, k_min=1, k_max=10, random_state=42, n_init=10, show_plot=True):
    """
    Analisis elbow untuk menentukan jumlah cluster optimal.
    Menggunakan heuristik: K dengan penurunan inertia terbesar.
    """
    k_values = list(range(k_min, min(k_max, len(coords)) + 1))
    inertias, silhouettes = [], []

    # Hitung inertia dan silhouette untuk setiap K
    for k in k_values:
        km = KMeans(n_clusters=k, n_init=n_init, random_state=random_state)
        km.fit(coords)
        inertias.append(km.inertia_)
        if k >= 2:
            silhouettes.append(silhouette_score(coords, km.labels_))
        else:
            silhouettes.append(np.nan)

    # Heuristic: cari K dengan penurunan inertia terbesar
    best_k = k_values[0]
    if len(k_values) >= 3:
        drops = [(inertias[i-1] - inertias[i]) / max(inertias[i-1], 1e-9) 
                 for i in range(1, len(inertias))]
        best_k = k_values[np.argmax(drops) + 1]

    # Plot hasil (opsional)
    if show_plot:
        fig, ax1 = plt.subplots(figsize=(10, 5))
        ax1.plot(k_values, inertias, marker='o', label='Inertia')
        ax1.set_xlabel('K (number of clusters)')
        ax1.set_ylabel('Inertia (SSE)')
        ax1.set_title('Elbow Method Analysis')
        
        # Tandai best K
        if best_k in k_values:
            best_idx = k_values.index(best_k)
            ax1.scatter([best_k], [inertias[best_idx]], s=100, color='red', zorder=5)
            ax1.annotate(f'K={best_k}', (best_k, inertias[best_idx]), 
                        xytext=(5, 5), textcoords='offset points')
        
        # Plot silhouette di sumbu kedua
        ax2 = ax1.twinx()
        ax2.plot(k_values, silhouettes, marker='x', linestyle='--', color='orange', label='Silhouette')
        ax2.set_ylabel('Silhouette Score')
        
        fig.tight_layout()
        plt.show()

    return {
        "k_values": k_values,
        "inertias": inertias,
        "silhouettes": silhouettes,
        "best_k": best_k
    }

def run_kmeans(coords, nodes, k, random_state=42, n_init=10):
    """
    Jalankan K-Means clustering dan return labels, clusters per group, dan centroids.
    """
    if k < 1 or k > len(coords):
        raise ValueError(f"k harus antara 1 dan {len(coords)}")
    
    km = KMeans(n_clusters=k, n_init=n_init, random_state=random_state)
    labels = km.fit_predict(coords)
    centroids = km.cluster_centers_

    # Kelompokkan nodes per cluster
    clusters = {c: [] for c in range(k)}
    for node, label in zip(nodes, labels):
        clusters[int(label)].append(node)

    return labels, clusters, centroids

def plot_clusters(coords, labels, centroids=None):
    """
    Visualisasi hasil clustering dengan scatter plot.
    Warna berbeda per cluster, centroid ditandai dengan segitiga.
    """
    labels = np.asarray(labels)
    k = int(labels.max()) + 1
    
    colors = plt.cm.Set3(np.linspace(0, 1, k))
    for c in range(k):
        pts = coords[labels == c]
        plt.scatter(pts[:, 0], pts[:, 1], label=f'Cluster {c}', color=colors[c], s=30, alpha=0.7)
    
    if centroids is not None:
        plt.scatter(centroids[:, 0], centroids[:, 1], marker='^', s=200, 
                   edgecolors='black', linewidths=1, color='red', label='Centroids', zorder=10)
    
    plt.legend()
    plt.title('K-Means Clustering Result')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.axis('equal')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# === Usage ===
info = elbow_analysis(coords, k_min=1, k_max=10, random_state=0, n_init=20, show_plot=True)
chosen_k = info["best_k"]
print(f"Recommended K: {chosen_k}")

labels, clusters, centroids = run_kmeans(coords, nodes, chosen_k)
print(f"Clusters: {chosen_k}")
for c, cluster_nodes in clusters.items():
    print(f"  Cluster {c}: {len(cluster_nodes)} points")
# Out:
# Recommended K: 2
# Clusters: 2
#   Cluster 0: 75 points
#   Cluster 1: 60 points

# %%
plot_clusters(coords, labels, centroids)

# %% [markdown]
# # Ortools for Benchmarking

# %%
# === OR-TOOLS VRP SOLVER (untuk benchmarking) ===
"""
Google OR-Tools VRP solver dengan multi-vehicle support.
Dipakai sebagai baseline/benchmark untuk membandingkan dengan metaheuristics.
"""

SCALE = 1000  # Precision scaling untuk integer distance matrix

def _build_distance_matrix(nodes_list, scale=SCALE):
    """Bangun integer distance matrix dari nodes (scaled untuk precision)"""
    N = len(nodes_list)
    return [[int(round(scale * float(D[idx[nodes_list[i]], idx[nodes_list[j]]])))
             for j in range(N)] for i in range(N)]

def _remap_labels_to_vehicles(labels, starts_ids):
    """Map cluster labels ke vehicle indices sesuai urutan starts_ids"""
    unique_labels = [labels[nodes.index(sid)] for sid in starts_ids]
    label_to_vehicle = {lbl: vid for vid, lbl in enumerate(unique_labels)}
    remapped = [label_to_vehicle[lbl] for lbl in labels]
    return remapped, label_to_vehicle

def create_data_model_clustered(nodes_list, labels, starts_ids, ends_ids=None, scale=SCALE):
    """
    Setup data model untuk OR-Tools VRP.
    
    Parameters:
    -----------
    nodes_list : list
        List ID nodes
    labels : array
        Cluster label per node (dari K-Means)
    starts_ids : list
        Starting node ID per vehicle
    ends_ids : list
        Ending node ID per vehicle (default = starts_ids for round-trip)
    """
    assert len(nodes_list) == len(labels), "nodes dan labels harus same length"
    
    K = len(starts_ids)
    if ends_ids is None:
        ends_ids = starts_ids[:]
    assert len(ends_ids) == K, "ends_ids harus same length dengan starts_ids"
    
    # Remap labels ke vehicle indices
    labels_remap, _ = _remap_labels_to_vehicles(labels, starts_ids)
    
    # Build distance matrix
    dist_matrix = _build_distance_matrix(nodes_list, scale=scale)
    
    # Node allowed vehicles (per cluster constraint)
    node_allowed = {i: [int(labels_remap[i])] for i in range(len(nodes_list))}
    
    # Convert starts/ends ke internal indices
    starts_idx = [nodes_list.index(x) for x in starts_ids]
    ends_idx = [nodes_list.index(x) for x in ends_ids]
    
    return {
        "distance_matrix": dist_matrix,
        "num_vehicles": K,
        "starts": starts_idx,
        "ends": ends_idx,
        "node_allowed_vehicles": node_allowed,
        "nodes": nodes_list,
        "scale": scale,
    }

def solve_vrp_clustered(nodes_list, labels, starts_ids, ends_ids=None, 
                        timeout_s=60, first_strategy="PATH_CHEAPEST_ARC",
                        metaheuristic="GUIDED_LOCAL_SEARCH"):
    """
    Solve clustered VRP menggunakan Google OR-Tools.
    
    Returns:
    --------
    routes_ids : list of lists
        Solusi routes (node IDs) per vehicle
    per_costs : list
        Cost per vehicle (float, unscaled)
    total_cost : float
        Total cost semua vehicle
    """
    data = create_data_model_clustered(nodes_list, labels, starts_ids, ends_ids)
    
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'],
                                           data['starts'],
                                           data['ends'])
    routing = pywrapcp.RoutingModel(manager)
    
    # Cost callback
    def distance_callback(from_idx, to_idx):
        f_node = manager.IndexToNode(from_idx)
        t_node = manager.IndexToNode(to_idx)
        return data['distance_matrix'][f_node][t_node]
    
    transit_idx = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_idx)
    
    # Enforce cluster constraints
    for node_id in range(len(nodes_list)):
        node_idx = manager.NodeToIndex(node_id)
        routing.SetAllowedVehiclesForIndex(data['node_allowed_vehicles'][node_id], node_idx)
    
    # Search parameters
    search_params = pywrapcp.DefaultRoutingSearchParameters()
    search_params.time_limit.seconds = int(timeout_s)
    search_params.first_solution_strategy = getattr(
        routing_enums_pb2.FirstSolutionStrategy, first_strategy)
    search_params.local_search_metaheuristic = getattr(
        routing_enums_pb2.LocalSearchMetaheuristic, metaheuristic)
    
    solution = routing.SolveWithParameters(search_params)
    if not solution:
        print("No solution found!")
        return None, [], float('inf')
    
    # Extract routes & costs
    routes_ids = []
    per_costs = []
    total_scaled = 0
    
    for v in range(data['num_vehicles']):
        index = routing.Start(v)
        route_idx = []
        while not routing.IsEnd(index):
            route_idx.append(manager.IndexToNode(index))
            index = solution.Value(routing.NextVar(index))
        route_idx.append(manager.IndexToNode(index))
        
        # Convert to node IDs
        route_ids = [data['nodes'][i] for i in route_idx]
        routes_ids.append(route_ids)
        
        # Calculate cost
        cost_scaled = sum(data['distance_matrix'][route_idx[i]][route_idx[i+1]]
                         for i in range(len(route_idx)-1))
        total_scaled += cost_scaled
        per_costs.append(cost_scaled / float(data['scale']))
    
    total_cost = total_scaled / float(data['scale'])
    return routes_ids, per_costs, total_cost

def solve_vrp_random_starts(nodes_list, labels, timeout_s=60, seed=None, round_trip=True):
    """
    Solve VRP dengan random start points per cluster (benchmark cepat).
    """
    rng = random.Random(seed)
    K = int(max(labels)) + 1
    
    # Kumpulkan nodes per cluster
    clusters = {c: [] for c in range(K)}
    for n, lab in zip(nodes_list, labels):
        clusters[int(lab)].append(n)
    
    # Random start per cluster
    starts = [rng.choice(clusters[c]) for c in range(K)]
    ends = starts if round_trip else [rng.choice(clusters[c]) for c in range(K)]
    
    routes, per_costs, total_cost = solve_vrp_clustered(
        nodes_list, labels, starts, ends, timeout_s=timeout_s)
    
    return {
        "starts": starts,
        "routes": routes,
        "per_costs": per_costs,
        "total_cost": total_cost
    }

# %%
res = solve_vrp_random_starts(nodes, labels, timeout_s=20, seed=None)
print("Start per kluster:", res["starts"])
print("Biaya per kluster:", res["per_costs"])
print("Total cost:", res["total_cost"])
for i, r in enumerate(res["routes"], 1):
    print(f"Rute kendaraan {i}:", r)
# Out:
# Start per kluster: [129, 13]
# Biaya per kluster: [735.655, 574.145]
# Total cost: 1309.8
# Rute kendaraan 1: [129, 67, 123, 43, 50, 101, 130, 1, 71, 55, 30, 115, 47, 76, 88, 77, 20, 60, 16, 85, 6, 41, 108, 44, 128, 58, 18, 116, 69, 84, 8, 135, 53, 38, 78, 114, 90, 3, 82, 125, 59, 27, 51, 80, 10, 117, 52, 29, 54, 110, 106, 15, 93, 62, 132, 112, 96, 37, 81, 40, 72, 34, 107, 23, 63, 111, 133, 95, 4, 42, 103, 11, 26, 124, 21, 129]
# Rute kendaraan 2: [13, 131, 98, 119, 75, 48, 2, 127, 66, 32, 92, 12, 70, 120, 25, 64, 113, 104, 39, 74, 97, 5, 91, 36, 105, 24, 94, 49, 9, 99, 56, 17, 35, 79, 22, 86, 7, 65, 83, 31, 102, 14, 134, 57, 73, 122, 28, 87, 121, 109, 68, 118, 19, 46, 45, 61, 126, 100, 33, 89, 13]

# %%
def _xy_of(node_id):
    # coords sejajar dengan `nodes`, dan `idx` memetakan id -> index
    return coords[idx[node_id], 0], coords[idx[node_id], 1]

def plot_routes_matplotlib(routes, starts=None, ends=None, show_ids=False, title="VRP routes"):
    fig, ax = plt.subplots(figsize=(7, 6))

    # plot semua titik sebagai background tipis
    ax.scatter(coords[:,0], coords[:,1], s=10, alpha=0.3, label="_all_points_bg")

    # gambar tiap rute
    for v, route in enumerate(routes):
        if len(route) == 0:
            continue

        # ambil koordinat sepanjang rute (termasuk node terakhir = end)
        xs, ys = [], []
        for nid in route:
            x, y = _xy_of(nid)
            xs.append(x); ys.append(y)

        # garis rutenya
        ax.plot(xs, ys, marker='o', linewidth=2, markersize=4, label=f"Vehicle {v}")

        # tandai start & end
        s_id = starts[v] if starts is not None else route[0]
        e_id = ends[v]   if ends is not None   else route[-1]
        sx, sy = _xy_of(s_id)
        ex, ey = _xy_of(e_id)

        ax.scatter([sx],[sy], marker='*', s=180, edgecolor='k', linewidths=0.8, zorder=5, label=f"_start_{v}")
        if e_id != s_id:
            ax.scatter([ex],[ey], marker='s', s=90, edgecolor='k', linewidths=0.8, zorder=5, label=f"_end_{v}")

        # optional: tulis ID di titik
        if show_ids:
            for nid in route:
                x, y = _xy_of(nid)
                ax.text(x, y, str(nid), fontsize=8, ha='right', va='bottom')

    ax.set_title(title)
    ax.set_xlabel("x"); ax.set_ylabel("y")
    ax.legend()
    ax.axis("equal")
    ax.grid(True, alpha=0.25)
    plt.tight_layout()
    plt.show()

plot_routes_matplotlib(
    routes=res["routes"],
    starts=res["starts"],
    ends=None,                # None -> otomatis dari list rute
    show_ids=False,
    title=f"VRP routes • total cost = {res['total_cost']:.2f}"
)

# %%
def plot_clustered_routes_matplotlib(cluster_routes, show_ids=False, title=None):
    fig, ax = plt.subplots(figsize=(7, 6))

    # background semua titik
    ax.scatter(coords[:,0], coords[:,1], s=10, alpha=0.25, label="_all_points_bg")

    for c, route in enumerate(cluster_routes):
        if not route:
            continue

        # urutan titik termasuk menutup ke awal (jika L>=2)
        xs, ys = [], []
        for nid in route:
            x, y = _xy_of(nid)
            xs.append(x); ys.append(y)
        if len(route) >= 2:
            x0, y0 = _xy_of(route[0])
            xs.append(x0); ys.append(y0)

        ax.plot(xs, ys, marker='o', linewidth=2, markersize=4, label=f"Cluster {c}")

        # tandai start (node pertama di list)
        sx, sy = _xy_of(route[0])
        ax.scatter([sx],[sy], marker='*', s=160, edgecolor='k', linewidths=0.8, zorder=5, label=f"_start_{c}")

        if show_ids:
            for nid in route:
                x, y = _xy_of(nid)
                ax.text(x, y, str(nid), fontsize=8, ha='right', va='bottom')

    if title is None:
        title = "Lovebird (clustered) routes"
    ax.set_title(title)
    ax.set_xlabel("x"); ax.set_ylabel("y")
    ax.legend()
    ax.axis("equal")
    ax.grid(True, alpha=0.25)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Lovebird Initial Algorithm

# %%
# === Mutation operators untuk TSP ===
def swap_two(tour, i, j):
    """Swap: tukar dua segment jika distance > 4, else gunakan interchange"""
    new = tour[:]
    if j - i < 4:
        return interchange(new, i, j)
    
    mid = new[i:j+1]
    k = len(mid) // 2
    new[i:i+k] = mid[k:]
    new[i+k:j+1] = mid[:k]
    return new

def flip(tour, i, j):
    """2-OPT: reverse segment [i:j+1]"""
    new = tour[:]
    new[i:j+1] = reversed(new[i:j+1])
    return new

def interchange(tour, i, j):
    """Obverse swap: tukar dua node"""
    new = tour[:]
    new[i], new[j] = new[j], new[i]
    return new

def slide(tour, i, j):
    """Slide: pindahkan node i ke posisi j"""
    new = tour[:]
    city = new.pop(i)
    new.insert(j, city)
    return new

def guided_swap(tour, i, j):
    """Hybrid: kombinasi flip + interchange"""
    new = flip(tour, i, j)
    return interchange(new, i, j)

def scramble(tour):
    """Random shuffle: acak urutan seluruh tour"""
    new = tour[:]
    random.shuffle(new)
    return new

# %%
# === Helper functions untuk Lovebird Algorithm ===

def roulette_wheel(population, fitness):
    """Selection: pilih individu dengan probabilitas sesuai fitness (1/cost)"""
    total = sum(fitness)
    spin = random.uniform(0, total)
    acc = 0
    for individual, fit in zip(population, fitness):
        acc += fit
        if acc >= spin:
            return individual
    return population[-1]

def _clusters_from_labels(nodes, labels):
    """
    Convert labels ke dictionary mapping cluster -> list of nodes.
    Nodes dalam cluster dijaga urutan sesuai input.
    """
    K = int(max(labels)) + 1
    clusters = {c: [] for c in range(K)}
    for node, label in zip(nodes, labels):
        clusters[int(label)].append(node)
    return clusters, K

def _calculate_multi_route_cost(routes):
    """Hitung total cost untuk solusi multi-route (per cluster)"""
    return sum(total_distance(r) for r in routes)

# %%
def lovebird_algorithm_clustered(labels, nodes, maxGeneration, popSize, seed=None):
    """
    Lovebird Algorithm dengan Local Search Stacking untuk Multi-Cluster TSP.
    
    Alur Utama:
    1. GA population: roulette wheel selection + mutation per cluster
    2. Local Search Stacking per kandidat:
       - SWAP: circular neighborhood swap sampai tidak ada perbaikan
       - FLIP: 2-OPT flip sampai tidak ada perbaikan
    3. Elitism: keep best solution
    
    Parameters:
    -----------
    labels : array
        Cluster label per node (dari K-Means)
    nodes : list
        List node IDs (sesuai urutan labels)
    maxGeneration : int
        Jumlah generasi GA
    popSize : int
        Ukuran populasi
    seed : int, optional
        Random seed untuk reproducibility
        
    Returns:
    --------
    best_solution : list of lists
        Rute terbaik per cluster
    best_fitness : float
        Total jarak terbaik
    history : list
        Perkembangan best_fitness per generasi
    per_cluster_costs : list
        Cost breakdown per cluster
    """
    rng = random.Random(seed)
    EPS = 1e-12

    # === Setup: build cluster mapping ===
    cluster_nodes, K = _clusters_from_labels(nodes, labels)

    # === Initialize population: random permutations per cluster ===
    def _random_individual():
        """Create one individual: random route per cluster"""
        indiv = []
        for c in range(K):
            route = cluster_nodes[c][:]
            rng.shuffle(route)
            indiv.append(route)
        return indiv

    population = [_random_individual() for _ in range(popSize)]
    pop_costs = [_calculate_multi_route_cost(ind) for ind in population]

    # Track best across generations
    best_idx = min(range(popSize), key=lambda i: pop_costs[i])
    best_solution = [r[:] for r in population[best_idx]]
    best_fitness = pop_costs[best_idx]
    history = [best_fitness]

    # === Main GA Loop ===
    for gen in range(maxGeneration):
        # Prepare fitness for roulette wheel
        fitness_values = [1.0/c if c > 0 else 1e9 for c in pop_costs]
        new_population = []
        new_costs = []

        for _ in range(popSize):
            # --- Selection: roulette wheel ---
            parent = roulette_wheel(population, fitness_values)
            child = [r[:] for r in parent]  # deep copy

            # --- Mutation: random cluster + random operator ---
            if K > 0:
                v = rng.randrange(K)
                route = child[v]
                L = len(route)
                
                if L > 1:
                    if rng.random() < 0.9 and L >= 2:
                        # Mutation operator
                        i_idx, j_idx = sorted(rng.sample(range(L), 2))
                        op = rng.choice([1, 2, 3, 4, 5])
                        
                        if op == 1:
                            route = swap_two(route, i_idx, j_idx)
                        elif op == 2:
                            route = flip(route, i_idx, j_idx)
                        elif op == 3:
                            route = interchange(route, i_idx, j_idx)
                        elif op == 4:
                            route = slide(route, i_idx, j_idx)
                        else:
                            route = guided_swap(route, i_idx, j_idx)
                    else:
                        # Scramble (10% probability)
                        route = scramble(route)
                    
                    child[v] = route

            # === LOCAL SEARCH STACKING: SWAP + FLIP (per candidate) ===
            route_costs = [total_distance(rr) for rr in child]
            total_cost = float(sum(route_costs))

            def _improve_route_stacking(route):
                """
                Local search stacking: SWAP circular, then FLIP circular.
                Return: (improved_route, total_delta)
                """
                Lr = len(route)
                if Lr <= 2:
                    return route, 0.0

                total_delta = 0.0
                improved_outer = True

                while improved_outer:
                    improved_outer = False

                    # ============ PHASE 1: SWAP (circular, first-improvement) ============
                    made_swap = True
                    while made_swap:
                        made_swap = False
                        if Lr <= 2:
                            break
                        
                        accepted = False
                        i = 0
                        while i < Lr - 1 and not accepted:
                            j = i + 1
                            while j < Lr and not accepted:
                                # Prepare neighbor nodes (circular)
                                a_idx, c_idx = i, j
                                aL = route[(a_idx - 1) % Lr]
                                a = route[a_idx]
                                b = route[(a_idx + 1) % Lr]
                                cL = route[(c_idx - 1) % Lr]
                                c = route[c_idx]
                                d = route[(c_idx + 1) % Lr]

                                # Check if adjacent
                                adjacent = (c_idx == a_idx + 1) or (a_idx == 0 and c_idx == Lr - 1)
                                
                                if adjacent:
                                    # Adjacent case: special edge calculation
                                    if c_idx == a_idx + 1:
                                        old = D[idx[aL], idx[a]] + D[idx[a], idx[c]] + D[idx[c], idx[d]]
                                        new = D[idx[aL], idx[c]] + D[idx[c], idx[a]] + D[idx[a], idx[d]]
                                    else:
                                        old = D[idx[cL], idx[c]] + D[idx[c], idx[a]] + D[idx[a], idx[b]]
                                        new = D[idx[cL], idx[a]] + D[idx[a], idx[c]] + D[idx[c], idx[b]]
                                else:
                                    # Non-adjacent case
                                    old = (D[idx[aL], idx[a]] + D[idx[a], idx[b]] +
                                           D[idx[cL], idx[c]] + D[idx[c], idx[d]])
                                    new = (D[idx[aL], idx[c]] + D[idx[c], idx[b]] +
                                           D[idx[cL], idx[a]] + D[idx[a], idx[d]])
                                
                                delta = new - old
                                
                                if delta < -EPS:
                                    # Improvement found: apply swap
                                    route[a_idx], route[c_idx] = route[c_idx], route[a_idx]
                                    total_delta += delta
                                    made_swap = True
                                    improved_outer = True
                                    accepted = True
                                else:
                                    j += 1
                            
                            if not accepted:
                                i += 1
                        
                        if made_swap:
                            break  # restart SWAP phase

                    # ============ PHASE 2: FLIP (2-OPT, circular, first-improvement) ============
                    made_flip = True
                    while made_flip:
                        made_flip = False
                        if Lr <= 2:
                            break
                        
                        accepted = False
                        i = 0
                        while i < Lr - 1 and not accepted:
                            j = i + 1
                            while j < Lr and not accepted:
                                # Skip same edge (circular)
                                if i == 0 and j == Lr - 1:
                                    j += 1
                                    continue
                                
                                # Calculate delta for 2-opt
                                ap = route[(i - 1) % Lr]
                                a = route[i]
                                c = route[j]
                                dn = route[(j + 1) % Lr]
                                
                                old = D[idx[ap], idx[a]] + D[idx[c], idx[dn]]
                                new = D[idx[ap], idx[c]] + D[idx[a], idx[dn]]
                                delta = new - old
                                
                                if delta < -EPS:
                                    # Improvement found: apply 2-opt
                                    route[i:j+1] = reversed(route[i:j+1])
                                    total_delta += delta
                                    made_flip = True
                                    improved_outer = True
                                    accepted = True
                                else:
                                    j += 1
                            
                            if not accepted:
                                i += 1
                        
                        if made_flip:
                            break  # restart FLIP phase

                return route, total_delta

            # === Apply local search stacking to all clusters ===
            for v in range(K):
                route_before = child[v]
                route_after, delta = _improve_route_stacking(route_before)
                
                if abs(delta) > EPS:
                    child[v] = route_after
                    route_costs[v] += delta
                    total_cost += delta

            new_population.append(child)
            new_costs.append(total_cost)

        # === Elitism: keep best ===
        gen_best_idx = min(range(popSize), key=lambda i: new_costs[i])
        if new_costs[gen_best_idx] < best_fitness - EPS:
            best_fitness = new_costs[gen_best_idx]
            best_solution = [r[:] for r in new_population[gen_best_idx]]

        # Update for next generation
        population = new_population
        pop_costs = new_costs
        history.append(best_fitness)

    # === Final stats ===
    per_cluster_costs = [total_distance(r) for r in best_solution]
    best_fitness = float(sum(per_cluster_costs))
    
    return best_solution, best_fitness, history, per_cluster_costs

# %%
# labels = ...   # hasil KMeans, sejajar dengan nodes
best_sol_l, total_cost_l, hist_l, per_costs_l = lovebird_algorithm_clustered(
    labels, nodes, maxGeneration=10, popSize=10
)

print("Biaya per kluster:", per_costs_l)
print("Total biaya:", total_cost_l)
for i, r in enumerate(best_sol_l, 1):
    print(f"Rute kluster {i} (|r|={len(r)}):", r)
# Out:
# Biaya per kluster: [737.053788333985, 577.2880556665764]
# Total biaya: 1314.3418440005614
# Rute kluster 1 (|r|=75): [96, 8, 84, 38, 69, 116, 41, 108, 6, 85, 16, 60, 20, 77, 88, 76, 47, 115, 30, 55, 71, 1, 130, 101, 50, 43, 123, 67, 129, 21, 124, 26, 11, 103, 42, 4, 95, 133, 111, 63, 23, 107, 34, 72, 40, 81, 37, 62, 93, 15, 106, 110, 54, 29, 52, 117, 10, 80, 51, 27, 59, 125, 82, 3, 90, 114, 44, 128, 58, 18, 78, 53, 135, 112, 132]
# Rute kluster 2 (|r|=60): [89, 13, 131, 98, 119, 75, 48, 2, 127, 66, 32, 92, 12, 70, 120, 25, 64, 113, 104, 39, 74, 5, 91, 36, 105, 24, 94, 49, 9, 99, 56, 17, 35, 79, 22, 86, 7, 65, 97, 31, 83, 102, 14, 134, 57, 73, 122, 28, 87, 121, 109, 19, 46, 45, 61, 118, 68, 126, 100, 33]

# %%
# Plot history
plt.figure(figsize=(8,4))
plt.plot(hist_l, marker='o')
plt.title("Perkembangan Fitness Lovebird Algorithm")
plt.xlabel("Generasi")
plt.ylabel("Total Distance")
plt.grid(True)
plt.show()

# %%
# --- contoh pakai hasil lovebird ---
plot_clustered_routes_matplotlib(
    best_sol_l,
    show_ids=False,
    title=f"Lovebird Clustered • total cost = {total_cost_l:.2f}"
)

# %% [markdown]
# # Local Search Algorithm

# %%
def two_opt_local_search(
    maxLoop=100,
    clusters=None,
    labels=None, nodes=None,
    initial_solution=None,
    time_budget=None,
    check_every=4096
):

    # === Time control ===
    t0 = time.perf_counter()
    def time_up():
        return (time_budget is not None) and ((time.perf_counter() - t0) >= time_budget)

    # === Initialize solution (pilih source dengan prioritas) ===
    if clusters is not None:
        current = [r[:] for r in clusters if len(r) > 0]
    elif (labels is not None) and (nodes is not None):
        # Dari hasil K-Means: kumpulkan nodes per cluster
        lab = np.asarray(labels)
        K = int(lab.max()) + 1 if lab.size > 0 else 0
        cluster_dict = {c: [] for c in range(K)}
        for node, label in zip(nodes, lab):
            cluster_dict[int(label)].append(node)
        
        # Randomisasi urutan dalam setiap cluster
        current = []
        for c in range(K):
            if cluster_dict[c]:
                route = cluster_dict[c][:]
                random.shuffle(route)
                current.append(route)
    elif initial_solution is not None:
        current = [r[:] for r in initial_solution if len(r) > 0]
    else:
        # Fallback: single vehicle dengan semua nodes
        shuffled = ids[:]
        random.shuffle(shuffled)
        current = [shuffled]

    if len(current) == 0:
        return [], 0.0, [0.0], []

    # === Track best solution ===
    route_costs = [total_distance(r) for r in current]
    total_cost = float(sum(route_costs))
    best_solution = [r[:] for r in current]
    best_cost = total_cost
    history = [best_cost]

    EPS = 1e-12
    ops_count = 0

    # === 2-OPT local search: minimize dengan 2-edge exchange ===
    def improve_single_route(route):
        """
        Apply 2-OPT sampai tidak ada perbaikan pada satu route.
        Return: delta cost yang sudah terakumulasi
        """
        L = len(route)
        if L <= 2:
            return 0.0
        
        total_delta = 0.0
        improved = True
        
        while improved:
            improved = False
            accepted = False
            
            # First-improvement: terima perbaikan pertama yang ditemukan
            i = 0
            while i < L - 1 and not accepted:
                j = i + 1
                while j < L and not accepted:
                    # Time budget throttling
                    nonlocal ops_count
                    ops_count += 1
                    if (ops_count % check_every == 0) and time_up():
                        return total_delta  # keluar dengan delta yang sudah terkumpul
                    
                    # Skip jika potong edge yang sama (circular tour)
                    if i == 0 and j == L - 1:
                        j += 1
                        continue
                    
                    # Hitung delta untuk 2-opt swap
                    # Remove edges (i-1, i) dan (j, j+1)
                    # Add edges (i-1, j) dan (i, j+1)
                    ap = route[(i - 1) % L]
                    a = route[i]
                    c = route[j]
                    dn = route[(j + 1) % L]
                    
                    old_dist = D[idx[ap], idx[a]] + D[idx[c], idx[dn]]
                    new_dist = D[idx[ap], idx[c]] + D[idx[a], idx[dn]]
                    delta = new_dist - old_dist
                    
                    if delta < -EPS:  # Improvement found
                        route[i:j+1] = reversed(route[i:j+1])
                        total_delta += delta
                        improved = True
                        accepted = True
                    else:
                        j += 1
                
                if not accepted:
                    i += 1
        
        return total_delta

    # === Main optimization loop ===
    for iteration in range(maxLoop):
        if time_up():
            break
        
        # Improve SEMUA route sampai lokal optimum
        any_improved = True
        while any_improved and (not time_up()):
            any_improved = False
            for v in range(len(current)):
                if time_up():
                    break
                
                delta = improve_single_route(current[v])
                if abs(delta) > EPS:
                    route_costs[v] += delta
                    total_cost += delta
                    any_improved = True
        
        # Update best solution
        if total_cost < best_cost - EPS:
            best_cost = float(total_cost)
            best_solution = [r[:] for r in current]
        
        if time_up():
            break
        
        # Recompute & track history
        route_costs = [total_distance(r) for r in current]
        total_cost = float(sum(route_costs))
        history.append(best_cost)
    
    per_cluster_costs = [total_distance(r) for r in best_solution]
    best_cost = float(sum(per_cluster_costs))
    
    return best_solution, best_cost, history, per_cluster_costs

# %%
best_sol_ll, total_cost_ll, hist_ll, per_costs_ll = two_opt_local_search(
    maxLoop=3,
    labels=labels,
    nodes=nodes,
    time_budget=None
)

print("Biaya per kluster:", per_costs_ll)
print("Total biaya:", total_cost_ll)
for i, r in enumerate(best_sol_ll, 1):
    print(f"Rute kluster {i} (|r|={len(r)}):", r)
# Out:
# Biaya per kluster: [747.1274076951331, 590.1549403193244]
# Total biaya: 1337.2823480144575
# Rute kluster 1 (|r|=75): [11, 26, 124, 21, 129, 67, 123, 43, 50, 101, 130, 1, 71, 55, 30, 115, 47, 76, 88, 77, 20, 60, 16, 85, 6, 108, 44, 128, 58, 41, 116, 18, 69, 84, 8, 96, 37, 62, 93, 132, 112, 135, 53, 38, 78, 114, 90, 3, 82, 125, 59, 27, 51, 80, 10, 117, 52, 29, 54, 110, 106, 15, 81, 40, 72, 34, 107, 23, 63, 111, 133, 95, 4, 42, 103]
# Rute kluster 2 (|r|=60): [83, 102, 14, 134, 57, 73, 122, 28, 87, 121, 109, 19, 46, 45, 61, 126, 118, 68, 100, 33, 89, 13, 131, 98, 119, 75, 48, 2, 127, 66, 32, 74, 39, 92, 104, 12, 113, 70, 64, 25, 120, 24, 94, 49, 9, 99, 56, 17, 35, 79, 22, 86, 7, 65, 105, 36, 91, 5, 97, 31]

# %%
# Plot history
plt.figure(figsize=(8,4))
plt.plot(hist_ll, marker='o')
plt.title("Perkembangan Fitness Local Search Algorithm")
plt.xlabel("Generasi")
plt.ylabel("Total Distance")
plt.grid(True)
plt.show()

# %%
# --- contoh pakai hasil lovebird ---
plot_clustered_routes_matplotlib(
    best_sol_ll,
    show_ids=False,
    title=f"Local Lovebird Clustered • total cost = {total_cost_ll:.2f}"
)

# %% [markdown]
# # Iterated Lovebird Algorithm

# %%
def cheapest_insertion_build(node_list):

    if not node_list:
        return []
    if len(node_list) <= 2:
        return node_list[:]

    # 1. Start with the first node (depot or arbitrary start)
    # Since we want a closed loop, we treat it as a subtour.
    tour = [node_list[0]]
    unvisited = set(node_list[1:])

    # 2. Initialize subtour with the nearest neighbor to the start node
    # to form the first edge (or stick with single node if preferred, 
    # but edges define cost better).
    if unvisited:
        u0_idx = idx[tour[0]]
        # Find node in unvisited closest to tour[0]
        next_node = min(unvisited, key=lambda x: D[u0_idx, idx[x]])
        tour.append(next_node)
        unvisited.remove(next_node)

    # 3. Iteratively insert remaining nodes
    while unvisited:
        best_delta = float('inf')
        best_node = None
        best_pos = -1

        for candidate in unvisited:
            c_idx = idx[candidate]
            
            # Try inserting 'candidate' between every pair (u, v) in current tour
            for i in range(len(tour)):
                u = tour[i]
                v = tour[(i + 1) % len(tour)] # Wrap around for circularity
                
                u_i = idx[u]
                v_i = idx[v]
                
                # Cost of insertion = d(u, c) + d(c, v) - d(u, v)
                delta = D[u_i, c_idx] + D[c_idx, v_i] - D[u_i, v_i]
                
                if delta < best_delta:
                    best_delta = delta
                    best_node = candidate
                    best_pos = i + 1
        
        # Insert the best node found
        if best_node is not None:
            tour.insert(best_pos, best_node)
            unvisited.remove(best_node)
            
    return tour

# %%
def double_bridge(route):
    L = len(route)
    if L < 8:
        return route[:]  # sama seperti semula
    rnd = random
    i1, i2, i3, i4 = sorted(rnd.sample(range(L), 4))
    segA = route[:i1]
    segB = route[i1:i2]
    segC = route[i2:i3]
    segD = route[i3:i4]
    segE = route[i4:]
    # varian klasik (tidak diubah)
    return segA + segC + segB + segD + segE

def double_bridge_multi(solution, min_len=8):
    """Terapkan double-bridge ke satu rute dalam solusi multi-rute."""
    new_sol = [r[:] for r in solution]
    rnd = random

    # pilih rute yang kandidat (panjang >= min_len)
    cand = [i for i, r in enumerate(new_sol) if len(r) >= min_len]
    if not cand:
        # fallback: kalau semua pendek, coba minimal len >= 4
        cand = [i for i, r in enumerate(new_sol) if len(r) >= 4]
        if not cand:
            return new_sol  # gak ada yang bisa di-double-bridge

    v = rnd.choice(cand)
    new_sol[v] = double_bridge(new_sol[v])  # pakai fungsi double_bridge lama milikmu
    return new_sol

# %%
def iterated_lovebird(
    max_iter=30,
    local_gen=120,
    clusters=None,
    labels=None, nodes=None,
    initial_solution=None,
    seed=None,
    budget_s=None,
    init_mutations=20
):
    """Iterated Local Search dengan operator perturbasi: double-bridge multi-route."""
    if seed is not None:
        random.seed(seed)

    def _init_solution():
        if clusters: return [r[:] for r in clusters if r]
        lab_arr = np.asarray(labels)
        K = int(lab_arr.max()) + 1
        tmp = {c: [] for c in range(K)}
        for n, l in zip(nodes, lab_arr):
            tmp[int(l)].append(n)
        return [cheapest_insertion_build(tmp[c]) for c in range(K) if tmp[c]]

    ls = two_opt_local_search

    SAFETY = 0.05
    t_start = time.perf_counter()
    deadline = (t_start + budget_s) if (budget_s is not None) else None

    def time_left():
        return None if deadline is None else max(0.0, deadline - time.perf_counter())

    # === 1) Initial solution ===
    start_solution = _init_solution()
    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in start_solution]
        best_cost = sum(total_distance(r) for r in best_sol)
        return best_sol, float(best_cost), [float(best_cost)]

    # === 2) Lovebird mutation phase (opsional) ===
    best_seed = [r[:] for r in start_solution]
    best_seed_cost = sum(total_distance(r) for r in best_seed)

    lovebird_ops = [swap_two, flip, interchange, slide, guided_swap]
    for _ in range(init_mutations):
        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break
        
        cand = [r[:] for r in start_solution]
        route_indices = [i for i, r in enumerate(cand) if len(r) >= 2]
        if not route_indices:
            break
        
        v = random.choice(route_indices)
        route = cand[v][:]
        
        if random.random() < 0.9:
            L = len(route)
            if L >= 2:
                i, j = sorted(random.sample(range(L), 2))
                op = random.choice(lovebird_ops)
                new_route = op(route, i, j)
            else:
                continue
        else:
            new_route = scramble(route)
        
        cand[v] = new_route
        cand_cost = sum(total_distance(r) for r in cand)
        
        if cand_cost < best_seed_cost - 1e-9:
            best_seed = cand
            best_seed_cost = cand_cost

    # === 3) Local search awal ===
    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in best_seed]
        best_cost = sum(total_distance(r) for r in best_sol)
        return best_sol, float(best_cost), [float(best_cost)]

    best_sol, best_cost, _hist0, _ = ls(
        maxLoop=local_gen,
        clusters=best_seed,
        time_budget=(rem - SAFETY) if rem is not None else None
    )
    history = [best_cost]

    # === 4) Pure ILS loop ===
    for _ in range(max_iter):
        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break

        perturbed = double_bridge_multi(best_sol)

        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break

        imp_sol, imp_cost, _, _ = ls(
            maxLoop=local_gen,
            clusters=perturbed,
            time_budget=(rem - SAFETY) if rem is not None else None
        )

        if imp_cost < best_cost - 1e-9:
            best_sol = [r[:] for r in imp_sol]
            best_cost = imp_cost

        history.append(best_cost)

    return best_sol, float(best_cost), history

# %%
best_sol_il, best_cost_il, hist_il = iterated_lovebird(
    max_iter=100, local_gen=10,
    labels=labels, nodes=nodes,
    budget_s=20.0
)

# Ringkasan biaya
per_costs_il = [total_distance(r) for r in best_sol_il]  # biaya per kluster
total_cost_il = sum(per_costs_il)                         # sama dengan best_cost (cek konsistensi)

print("Biaya per kluster:", per_costs_il)
print("Total biaya (sum):", total_cost_il)
print("Total biaya (best_cost dari ILS):", best_cost_il)

# Cetak rute per kluster
for i, r in enumerate(best_sol_il, 1):
    print(f"Rute kluster {i} (|r|={len(r)}): {r}")
# Out:
# Biaya per kluster: [744.8690134553704, 580.2345659356934]
# Total biaya (sum): 1325.1035793910637
# Total biaya (best_cost dari ILS): 1325.1035793910637
# Rute kluster 1 (|r|=75): [101, 130, 1, 71, 55, 30, 115, 47, 88, 77, 20, 76, 60, 16, 85, 6, 108, 44, 128, 58, 41, 116, 18, 69, 84, 8, 135, 53, 38, 78, 114, 90, 3, 82, 125, 59, 27, 51, 80, 10, 117, 52, 29, 54, 110, 93, 132, 112, 96, 62, 37, 81, 15, 106, 40, 72, 34, 107, 23, 63, 111, 133, 95, 4, 42, 103, 11, 26, 124, 21, 129, 50, 67, 123, 43]
# Rute kluster 2 (|r|=60): [66, 74, 39, 104, 113, 64, 25, 120, 70, 12, 92, 32, 127, 2, 48, 98, 131, 89, 33, 100, 126, 61, 45, 46, 19, 118, 68, 109, 121, 87, 28, 122, 73, 57, 134, 14, 102, 83, 65, 7, 86, 22, 79, 35, 17, 56, 99, 9, 49, 94, 24, 105, 36, 91, 5, 97, 31, 13, 119, 75]

# %%
# Plot history
plt.figure(figsize=(8,4))
plt.plot(hist_il, marker='o')
plt.title("Perkembangan Fitness Iterated Lovebird Algorithm")
plt.xlabel("Generasi")
plt.ylabel("Total Distance")
plt.grid(True)
plt.show()

# %%
# --- contoh pakai hasil lovebird ---
plot_clustered_routes_matplotlib(
    best_sol_il,
    show_ids=False,
    title=f"Iterated Lovebird Clustered • total cost = {best_cost_il:.2f}"
)

# %%
def iterated_local_search(
    max_iter=30,
    local_gen=120,
    clusters=None,
    labels=None, nodes=None,
    initial_solution=None,
    seed=None,
    budget_s=None
):
    """Iterated Local Search dengan operator perturbasi: double-bridge multi-route."""
    if seed is not None:
        random.seed(seed)

    def _init_solution_from_inputs():
        if clusters is not None:
            cur = [r[:] for r in clusters if len(r) > 0]
            return cur if cur else [[]]
        elif (labels is not None) and (nodes is not None):
            lab_arr = np.asarray(labels)
            K = int(lab_arr.max()) + 1 if lab_arr.size > 0 else 0
            tmp = {c: [] for c in range(K)}
            for n, l in zip(nodes, lab_arr):
                tmp[int(l)].append(n)
            cur = []
            for c in range(K):
                if tmp[c]:
                    r = tmp[c][:]
                    random.shuffle(r)
                    cur.append(r)
            return cur if cur else [[]]
        elif initial_solution is not None:
            return [r[:] for r in initial_solution if len(r) > 0] or [[]]
        else:
            ids_copy = ids[:]
            random.shuffle(ids_copy)
            return [ids_copy]

    ls = two_opt_local_search

    SAFETY = 0.05
    t_start = time.perf_counter()
    deadline = (t_start + budget_s) if (budget_s is not None) else None

    def time_left():
        return None if deadline is None else max(0.0, deadline - time.perf_counter())

    # === 1) Initial solution ===
    start_solution = _init_solution_from_inputs()
    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in start_solution]
        best_cost = sum(total_distance(r) for r in best_sol)
        return best_sol, float(best_cost), [float(best_cost)]

    # === 2) Lovebird mutation phase (opsional) ===
    best_seed = [r[:] for r in start_solution]
    best_seed_cost = sum(total_distance(r) for r in best_seed)

    # === 3) Local search awal ===
    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in best_seed]
        best_cost = sum(total_distance(r) for r in best_sol)
        return best_sol, float(best_cost), [float(best_cost)]

    best_sol, best_cost, _hist0, _ = ls(
        maxLoop=local_gen,
        clusters=best_seed,
        time_budget=(rem - SAFETY) if rem is not None else None
    )
    history = [best_cost]

    # === 4) Pure ILS loop ===
    for _ in range(max_iter):
        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break

        perturbed = double_bridge_multi(best_sol)

        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break

        imp_sol, imp_cost, _, _ = ls(
            maxLoop=local_gen,
            clusters=perturbed,
            time_budget=(rem - SAFETY) if rem is not None else None
        )

        if imp_cost < best_cost - 1e-9:
            best_sol = [r[:] for r in imp_sol]
            best_cost = imp_cost

        history.append(best_cost)

    return best_sol, float(best_cost), history

# %% [markdown]
# ## ILS DEBUGGING

# %%
def iterated_lovebird_debug(
    max_iter=30,
    local_gen=120,
    clusters=None,
    labels=None, nodes=None,
    initial_solution=None,
    seed=None,
    budget_s=None,
    init_mutations=20
):
    """Debug version of iterated_lovebird dengan logging detail per iterasi."""
    if seed is not None:
        random.seed(seed)

    def _init_solution_from_inputs():
        if clusters is not None:
            cur = [r[:] for r in clusters if len(r) > 0]
            return cur if cur else [[]]
        elif (labels is not None) and (nodes is not None):
            lab_arr = np.asarray(labels)
            K = int(lab_arr.max()) + 1 if lab_arr.size > 0 else 0
            tmp = {c: [] for c in range(K)}
            for n, l in zip(nodes, lab_arr):
                tmp[int(l)].append(n)
            cur = []
            for c in range(K):
                if tmp[c]:
                    r = tmp[c][:]
                    random.shuffle(r)
                    cur.append(r)
            return cur if cur else [[]]
        elif initial_solution is not None:
            return [r[:] for r in initial_solution if len(r) > 0] or [[]]
        else:
            ids_copy = ids[:]
            random.shuffle(ids_copy)
            return [ids_copy]

    ls = two_opt_local_search

    SAFETY = 0.05
    t_start = time.perf_counter()
    deadline = (t_start + budget_s) if (budget_s is not None) else None

    def time_left():
        return None if deadline is None else max(0.0, deadline - time.perf_counter())

    # === 1) Initial solution ===
    start_solution = _init_solution_from_inputs()
    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in start_solution]
        best_cost = sum(total_distance(r) for r in best_sol)
        return best_sol, float(best_cost), [float(best_cost)], []

    # === 2) Lovebird mutation phase ===
    best_seed = [r[:] for r in start_solution]
    best_seed_cost = sum(total_distance(r) for r in best_seed)

    lovebird_ops = [swap_two, flip, interchange, slide, guided_swap]
    for _ in range(init_mutations):
        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break
        
        cand = [r[:] for r in start_solution]
        route_indices = [i for i, r in enumerate(cand) if len(r) >= 2]
        if not route_indices:
            break
        
        v = random.choice(route_indices)
        route = cand[v][:]
        
        if random.random() < 0.9:
            L = len(route)
            if L >= 2:
                i, j = sorted(random.sample(range(L), 2))
                op = random.choice(lovebird_ops)
                new_route = op(route, i, j)
            else:
                continue
        else:
            new_route = scramble(route)
        
        cand[v] = new_route
        cand_cost = sum(total_distance(r) for r in cand)
        
        if cand_cost < best_seed_cost - 1e-9:
            best_seed = cand
            best_seed_cost = cand_cost

    # === 3) Local search awal ===
    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in best_seed]
        best_cost = sum(total_distance(r) for r in best_sol)
        return best_sol, float(best_cost), [float(best_cost)], []

    best_sol, best_cost, _hist0, _ = ls(
        maxLoop=local_gen,
        clusters=best_seed,
        time_budget=(rem - SAFETY) if rem is not None else None
    )
    history = [best_cost]

    # === 4) ILS loop dengan logging ===
    iter_logs = []
    for it in range(1, max_iter + 1):
        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break

        best_cost_before = best_cost
        perturbed = double_bridge_multi(best_sol)
        pert_cost = sum(total_distance(r) for r in perturbed)

        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break

        imp_sol, imp_cost, _, _ = ls(
            maxLoop=local_gen,
            clusters=perturbed,
            time_budget=(rem - SAFETY) if rem is not None else None
        )

        accepted = False
        if imp_cost < best_cost - 1e-9:
            best_sol = [r[:] for r in imp_sol]
            best_cost = imp_cost
            accepted = True

        history.append(best_cost)
        iter_logs.append({
            "iter": it,
            "time": time.perf_counter() - t_start,
            "best_before": float(best_cost_before),
            "pert_cost": float(pert_cost),
            "imp_cost": float(imp_cost),
            "best_after": float(best_cost),
            "accepted": bool(accepted),
        })

        rem = time_left()
        if rem is not None and rem <= SAFETY:
            break

    return best_sol, float(best_cost), history, iter_logs

# %%
best_sol, best_cost, history, logs = iterated_lovebird_debug(
    max_iter=500,
    local_gen=5,
    labels=labels,
    nodes=nodes,
    budget_s=None,
    init_mutations=20,
    seed=42  # biar repeatable
)

print("Final cost:", best_cost)
for entry in logs:
    print(
        f"iter={entry['iter']:2d} "
        f"best_before={entry['best_before']:.2f} "
        f"pert={entry['pert_cost']:.2f} "
        f"imp={entry['imp_cost']:.2f} "
        f"best_after={entry['best_after']:.2f} "
        f"accepted={entry['accepted']}"
    )
# Out:
# Final cost: 1309.4467394256365
# iter= 1 best_before=1340.86 pert=1422.42 imp=1340.86 best_after=1340.86 accepted=False
# iter= 2 best_before=1340.86 pert=1377.77 imp=1343.22 best_after=1340.86 accepted=False
# iter= 3 best_before=1340.86 pert=1407.00 imp=1341.64 best_after=1340.86 accepted=False
# iter= 4 best_before=1340.86 pert=1443.39 imp=1343.52 best_after=1340.86 accepted=False
# iter= 5 best_before=1340.86 pert=1415.27 imp=1340.86 best_after=1340.86 accepted=False
# iter= 6 best_before=1340.86 pert=1450.04 imp=1343.25 best_after=1340.86 accepted=False
# iter= 7 best_before=1340.86 pert=1416.28 imp=1340.86 best_after=1340.86 accepted=False
# iter= 8 best_before=1340.86 pert=1494.67 imp=1343.25 best_after=1340.86 accepted=False
# iter= 9 best_before=1340.86 pert=1537.32 imp=1336.98 best_after=1336.98 accepted=True
# iter=10 best_before=1336.98 pert=1499.57 imp=1352.34 best_after=1336.98 accepted=False
# iter=11 best_before=1336.98 pert=1579.74 imp=1334.96 best_after=1334.96 accepted=True
# iter=12 best_before=1334.96 pert=1440.94 imp=1334.54 best_after=1334.54 accepted=True
# iter=13 best_before=1334.54 pert=1409.54 imp=1336.90 best_after=1334.54 accepted=False
# iter=14 best_before=1334.54 pert=1521.25 imp=1339.09 best_after=1334.54 accepted=False
# iter=15 best_before=1334.54 pert=1445.13 imp=1336.33 best_after=1334.54 accepted=False
# iter=16 best_before=1334.54 pert=1530.12 imp=1334.54 best_after=1334.54 accepted=False
# iter=17 best_before=1334.54 pert=1484.09 imp=1322.68 best_after=1322.68 accepted=True
# iter=18 best_before=1322.68 pert=1400.05 imp=1322.28 best_after=1322.28 accepted=True
# iter=19 best_before=1322.28 pert=1391.58 imp=1322.28 best_after=1322.28 accepted=False
# iter=20 best_before=1322.28 pert=1445.64 imp=1322.28 best_after=1322.28 accepted=False
# iter=21 best_before=1322.28 pert=1502.44 imp=1322.28 best_after=1322.28 accepted=False
# iter=22 best_before=1322.28 pert=1507.63 imp=1322.28 best_after=1322.28 accepted=False
# iter=23 best_before=1322.28 pert=1616.54 imp=1322.28 best_after=1322.28 accepted=False
# iter=24 best_before=1322.28 pert=1508.04 imp=1322.28 best_after=1322.28 accepted=False
# iter=25 best_before=1322.28 pert=1523.92 imp=1318.02 best_after=1318.02 accepted=True
# iter=26 best_before=1318.02 pert=1421.77 imp=1318.02 best_after=1318.02 accepted=False
# iter=27 best_before=1318.02 pert=1419.22 imp=1318.02 best_after=1318.02 accepted=False
# iter=28 best_before=1318.02 pert=1523.20 imp=1318.73 best_after=1318.02 accepted=False
# iter=29 best_before=1318.02 pert=1418.83 imp=1320.50 best_after=1318.02 accepted=False
# iter=30 best_before=1318.02 pert=1417.62 imp=1318.02 best_after=1318.02 accepted=False
# iter=31 best_before=1318.02 pert=1404.67 imp=1318.02 best_after=1318.02 accepted=False
# iter=32 best_before=1318.02 pert=1483.75 imp=1322.28 best_after=1318.02 accepted=False
# iter=33 best_before=1318.02 pert=1466.01 imp=1338.04 best_after=1318.02 accepted=False
# iter=34 best_before=1318.02 pert=1415.97 imp=1318.02 best_after=1318.02 accepted=False
# iter=35 best_before=1318.02 pert=1435.76 imp=1318.02 best_after=1318.02 accepted=False
# iter=36 best_before=1318.02 pert=1414.76 imp=1321.10 best_after=1318.02 accepted=False
# iter=37 best_before=1318.02 pert=1449.71 imp=1318.02 best_after=1318.02 accepted=False
# iter=38 best_before=1318.02 pert=1652.84 imp=1318.02 best_after=1318.02 accepted=False
# iter=39 best_before=1318.02 pert=1442.15 imp=1318.02 best_after=1318.02 accepted=False
# iter=40 best_before=1318.02 pert=1417.56 imp=1317.53 best_after=1317.53 accepted=True
# iter=41 best_before=1317.53 pert=1550.69 imp=1320.61 best_after=1317.53 accepted=False
# iter=42 best_before=1317.53 pert=1493.03 imp=1317.53 best_after=1317.53 accepted=False
# iter=43 best_before=1317.53 pert=1360.58 imp=1318.52 best_after=1317.53 accepted=False
# iter=44 best_before=1317.53 pert=1362.21 imp=1317.53 best_after=1317.53 accepted=False
# iter=45 best_before=1317.53 pert=1411.94 imp=1321.82 best_after=1317.53 accepted=False
# iter=46 best_before=1317.53 pert=1393.38 imp=1317.53 best_after=1317.53 accepted=False
# iter=47 best_before=1317.53 pert=1425.27 imp=1317.53 best_after=1317.53 accepted=False
# iter=48 best_before=1317.53 pert=1532.25 imp=1317.53 best_after=1317.53 accepted=False
# iter=49 best_before=1317.53 pert=1473.14 imp=1317.53 best_after=1317.53 accepted=False
# iter=50 best_before=1317.53 pert=1524.79 imp=1317.53 best_after=1317.53 accepted=False
# iter=51 best_before=1317.53 pert=1355.25 imp=1317.53 best_after=1317.53 accepted=False
# iter=52 best_before=1317.53 pert=1508.37 imp=1317.53 best_after=1317.53 accepted=False
# iter=53 best_before=1317.53 pert=1416.48 imp=1317.53 best_after=1317.53 accepted=False
# iter=54 best_before=1317.53 pert=1423.60 imp=1318.62 best_after=1317.53 accepted=False
# iter=55 best_before=1317.53 pert=1538.80 imp=1317.53 best_after=1317.53 accepted=False
# iter=56 best_before=1317.53 pert=1437.32 imp=1317.53 best_after=1317.53 accepted=False
# iter=57 best_before=1317.53 pert=1450.44 imp=1317.53 best_after=1317.53 accepted=False
# iter=58 best_before=1317.53 pert=1486.09 imp=1317.94 best_after=1317.53 accepted=False
# iter=59 best_before=1317.53 pert=1384.42 imp=1317.53 best_after=1317.53 accepted=False
# iter=60 best_before=1317.53 pert=1588.34 imp=1317.53 best_after=1317.53 accepted=False
# iter=61 best_before=1317.53 pert=1521.81 imp=1317.53 best_after=1317.53 accepted=False
# iter=62 best_before=1317.53 pert=1463.16 imp=1317.53 best_after=1317.53 accepted=False
# iter=63 best_before=1317.53 pert=1558.45 imp=1322.23 best_after=1317.53 accepted=False
# iter=64 best_before=1317.53 pert=1419.92 imp=1319.89 best_after=1317.53 accepted=False
# iter=65 best_before=1317.53 pert=1472.17 imp=1323.98 best_after=1317.53 accepted=False
# iter=66 best_before=1317.53 pert=1480.59 imp=1321.82 best_after=1317.53 accepted=False
# iter=67 best_before=1317.53 pert=1422.95 imp=1317.53 best_after=1317.53 accepted=False
# iter=68 best_before=1317.53 pert=1425.91 imp=1317.53 best_after=1317.53 accepted=False
# iter=69 best_before=1317.53 pert=1514.07 imp=1346.00 best_after=1317.53 accepted=False
# iter=70 best_before=1317.53 pert=1515.26 imp=1317.53 best_after=1317.53 accepted=False
# iter=71 best_before=1317.53 pert=1478.92 imp=1320.28 best_after=1317.53 accepted=False
# iter=72 best_before=1317.53 pert=1493.70 imp=1318.62 best_after=1317.53 accepted=False
# iter=73 best_before=1317.53 pert=1458.07 imp=1317.53 best_after=1317.53 accepted=False
# iter=74 best_before=1317.53 pert=1484.57 imp=1317.53 best_after=1317.53 accepted=False
# iter=75 best_before=1317.53 pert=1518.90 imp=1317.53 best_after=1317.53 accepted=False
# iter=76 best_before=1317.53 pert=1443.21 imp=1317.53 best_after=1317.53 accepted=False
# iter=77 best_before=1317.53 pert=1346.85 imp=1318.52 best_after=1317.53 accepted=False
# iter=78 best_before=1317.53 pert=1445.47 imp=1317.53 best_after=1317.53 accepted=False
# iter=79 best_before=1317.53 pert=1386.06 imp=1321.79 best_after=1317.53 accepted=False
# iter=80 best_before=1317.53 pert=1394.98 imp=1317.53 best_after=1317.53 accepted=False
# iter=81 best_before=1317.53 pert=1439.08 imp=1317.53 best_after=1317.53 accepted=False
# iter=82 best_before=1317.53 pert=1452.81 imp=1321.19 best_after=1317.53 accepted=False
# iter=83 best_before=1317.53 pert=1516.43 imp=1317.53 best_after=1317.53 accepted=False
# iter=84 best_before=1317.53 pert=1347.15 imp=1313.38 best_after=1313.38 accepted=True
# iter=85 best_before=1313.38 pert=1378.01 imp=1314.47 best_after=1313.38 accepted=False
# iter=86 best_before=1313.38 pert=1395.36 imp=1316.13 best_after=1313.38 accepted=False
# iter=87 best_before=1313.38 pert=1350.04 imp=1317.88 best_after=1313.38 accepted=False
# iter=88 best_before=1313.38 pert=1373.18 imp=1313.38 best_after=1313.38 accepted=False
# iter=89 best_before=1313.38 pert=1545.62 imp=1313.37 best_after=1313.37 accepted=True
# iter=90 best_before=1313.37 pert=1400.30 imp=1325.54 best_after=1313.37 accepted=False
# iter=91 best_before=1313.37 pert=1423.56 imp=1313.37 best_after=1313.37 accepted=False
# iter=92 best_before=1313.37 pert=1661.66 imp=1324.82 best_after=1313.37 accepted=False
# iter=93 best_before=1313.37 pert=1426.44 imp=1313.78 best_after=1313.37 accepted=False
# iter=94 best_before=1313.37 pert=1495.96 imp=1313.37 best_after=1313.37 accepted=False
# iter=95 best_before=1313.37 pert=1468.67 imp=1313.37 best_after=1313.37 accepted=False
# iter=96 best_before=1313.37 pert=1414.29 imp=1317.63 best_after=1313.37 accepted=False
# iter=97 best_before=1313.37 pert=1427.99 imp=1313.37 best_after=1313.37 accepted=False
# iter=98 best_before=1313.37 pert=1470.05 imp=1313.37 best_after=1313.37 accepted=False
# iter=99 best_before=1313.37 pert=1454.25 imp=1331.34 best_after=1313.37 accepted=False
# iter=100 best_before=1313.37 pert=1457.50 imp=1352.13 best_after=1313.37 accepted=False
# iter=101 best_before=1313.37 pert=1457.51 imp=1313.37 best_after=1313.37 accepted=False
# iter=102 best_before=1313.37 pert=1454.11 imp=1313.37 best_after=1313.37 accepted=False
# iter=103 best_before=1313.37 pert=1429.32 imp=1313.37 best_after=1313.37 accepted=False
# iter=104 best_before=1313.37 pert=1415.22 imp=1313.37 best_after=1313.37 accepted=False
# iter=105 best_before=1313.37 pert=1567.26 imp=1313.37 best_after=1313.37 accepted=False
# iter=106 best_before=1313.37 pert=1379.05 imp=1313.37 best_after=1313.37 accepted=False
# iter=107 best_before=1313.37 pert=1533.17 imp=1315.98 best_after=1313.37 accepted=False
# iter=108 best_before=1313.37 pert=1418.87 imp=1313.37 best_after=1313.37 accepted=False
# iter=109 best_before=1313.37 pert=1369.15 imp=1313.37 best_after=1313.37 accepted=False
# iter=110 best_before=1313.37 pert=1440.84 imp=1319.78 best_after=1313.37 accepted=False
# iter=111 best_before=1313.37 pert=1454.39 imp=1313.37 best_after=1313.37 accepted=False
# iter=112 best_before=1313.37 pert=1401.95 imp=1313.37 best_after=1313.37 accepted=False
# iter=113 best_before=1313.37 pert=1451.27 imp=1313.37 best_after=1313.37 accepted=False
# iter=114 best_before=1313.37 pert=1386.48 imp=1313.37 best_after=1313.37 accepted=False
# iter=115 best_before=1313.37 pert=1565.59 imp=1313.37 best_after=1313.37 accepted=False
# iter=116 best_before=1313.37 pert=1435.57 imp=1317.63 best_after=1313.37 accepted=False
# iter=117 best_before=1313.37 pert=1384.01 imp=1329.89 best_after=1313.37 accepted=False
# iter=118 best_before=1313.37 pert=1455.69 imp=1317.63 best_after=1313.37 accepted=False
# iter=119 best_before=1313.37 pert=1488.66 imp=1314.46 best_after=1313.37 accepted=False
# iter=120 best_before=1313.37 pert=1549.06 imp=1313.37 best_after=1313.37 accepted=False
# iter=121 best_before=1313.37 pert=1439.80 imp=1313.37 best_after=1313.37 accepted=False
# iter=122 best_before=1313.37 pert=1540.81 imp=1313.37 best_after=1313.37 accepted=False
# iter=123 best_before=1313.37 pert=1406.07 imp=1313.37 best_after=1313.37 accepted=False
# iter=124 best_before=1313.37 pert=1438.19 imp=1316.12 best_after=1313.37 accepted=False
# iter=125 best_before=1313.37 pert=1464.26 imp=1313.37 best_after=1313.37 accepted=False
# iter=126 best_before=1313.37 pert=1352.90 imp=1313.37 best_after=1313.37 accepted=False
# iter=127 best_before=1313.37 pert=1379.82 imp=1313.37 best_after=1313.37 accepted=False
# iter=128 best_before=1313.37 pert=1437.34 imp=1313.37 best_after=1313.37 accepted=False
# iter=129 best_before=1313.37 pert=1444.94 imp=1321.91 best_after=1313.37 accepted=False
# iter=130 best_before=1313.37 pert=1500.77 imp=1313.37 best_after=1313.37 accepted=False
# iter=131 best_before=1313.37 pert=1400.98 imp=1313.37 best_after=1313.37 accepted=False
# iter=132 best_before=1313.37 pert=1432.13 imp=1313.37 best_after=1313.37 accepted=False
# iter=133 best_before=1313.37 pert=1361.61 imp=1313.77 best_after=1313.37 accepted=False
# iter=134 best_before=1313.37 pert=1540.64 imp=1313.86 best_after=1313.37 accepted=False
# iter=135 best_before=1313.37 pert=1416.54 imp=1313.37 best_after=1313.37 accepted=False
# iter=136 best_before=1313.37 pert=1470.30 imp=1315.66 best_after=1313.37 accepted=False
# iter=137 best_before=1313.37 pert=1419.86 imp=1313.37 best_after=1313.37 accepted=False
# iter=138 best_before=1313.37 pert=1368.87 imp=1313.37 best_after=1313.37 accepted=False
# iter=139 best_before=1313.37 pert=1383.76 imp=1314.46 best_after=1313.37 accepted=False
# iter=140 best_before=1313.37 pert=1430.20 imp=1313.37 best_after=1313.37 accepted=False
# iter=141 best_before=1313.37 pert=1439.87 imp=1316.04 best_after=1313.37 accepted=False
# iter=142 best_before=1313.37 pert=1398.97 imp=1313.37 best_after=1313.37 accepted=False
# iter=143 best_before=1313.37 pert=1432.35 imp=1313.37 best_after=1313.37 accepted=False
# iter=144 best_before=1313.37 pert=1509.53 imp=1316.12 best_after=1313.37 accepted=False
# iter=145 best_before=1313.37 pert=1620.57 imp=1316.75 best_after=1313.37 accepted=False
# iter=146 best_before=1313.37 pert=1432.96 imp=1313.37 best_after=1313.37 accepted=False
# iter=147 best_before=1313.37 pert=1389.80 imp=1313.37 best_after=1313.37 accepted=False
# iter=148 best_before=1313.37 pert=1477.96 imp=1313.37 best_after=1313.37 accepted=False
# iter=149 best_before=1313.37 pert=1468.51 imp=1313.37 best_after=1313.37 accepted=False
# iter=150 best_before=1313.37 pert=1448.51 imp=1313.37 best_after=1313.37 accepted=False
# iter=151 best_before=1313.37 pert=1394.41 imp=1317.66 best_after=1313.37 accepted=False
# iter=152 best_before=1313.37 pert=1507.50 imp=1313.37 best_after=1313.37 accepted=False
# iter=153 best_before=1313.37 pert=1489.13 imp=1328.62 best_after=1313.37 accepted=False
# iter=154 best_before=1313.37 pert=1503.24 imp=1319.39 best_after=1313.37 accepted=False
# iter=155 best_before=1313.37 pert=1449.38 imp=1313.37 best_after=1313.37 accepted=False
# iter=156 best_before=1313.37 pert=1497.16 imp=1317.63 best_after=1313.37 accepted=False
# iter=157 best_before=1313.37 pert=1418.86 imp=1313.37 best_after=1313.37 accepted=False
# iter=158 best_before=1313.37 pert=1436.28 imp=1313.37 best_after=1313.37 accepted=False
# iter=159 best_before=1313.37 pert=1402.76 imp=1313.37 best_after=1313.37 accepted=False
# iter=160 best_before=1313.37 pert=1414.00 imp=1326.76 best_after=1313.37 accepted=False
# iter=161 best_before=1313.37 pert=1430.48 imp=1323.09 best_after=1313.37 accepted=False
# iter=162 best_before=1313.37 pert=1386.50 imp=1313.37 best_after=1313.37 accepted=False
# iter=163 best_before=1313.37 pert=1460.20 imp=1313.37 best_after=1313.37 accepted=False
# iter=164 best_before=1313.37 pert=1390.08 imp=1313.37 best_after=1313.37 accepted=False
# iter=165 best_before=1313.37 pert=1540.30 imp=1316.45 best_after=1313.37 accepted=False
# iter=166 best_before=1313.37 pert=1420.99 imp=1313.37 best_after=1313.37 accepted=False
# iter=167 best_before=1313.37 pert=1397.58 imp=1313.37 best_after=1313.37 accepted=False
# iter=168 best_before=1313.37 pert=1396.83 imp=1313.86 best_after=1313.37 accepted=False
# iter=169 best_before=1313.37 pert=1489.57 imp=1319.06 best_after=1313.37 accepted=False
# iter=170 best_before=1313.37 pert=1469.27 imp=1313.38 best_after=1313.37 accepted=False
# iter=171 best_before=1313.37 pert=1428.90 imp=1317.63 best_after=1313.37 accepted=False
# iter=172 best_before=1313.37 pert=1517.22 imp=1349.27 best_after=1313.37 accepted=False
# iter=173 best_before=1313.37 pert=1436.94 imp=1313.37 best_after=1313.37 accepted=False
# iter=174 best_before=1313.37 pert=1509.22 imp=1317.64 best_after=1313.37 accepted=False
# iter=175 best_before=1313.37 pert=1460.00 imp=1313.37 best_after=1313.37 accepted=False
# iter=176 best_before=1313.37 pert=1453.02 imp=1313.37 best_after=1313.37 accepted=False
# iter=177 best_before=1313.37 pert=1621.84 imp=1313.37 best_after=1313.37 accepted=False
# iter=178 best_before=1313.37 pert=1397.24 imp=1313.37 best_after=1313.37 accepted=False
# iter=179 best_before=1313.37 pert=1498.29 imp=1313.37 best_after=1313.37 accepted=False
# iter=180 best_before=1313.37 pert=1471.04 imp=1315.31 best_after=1313.37 accepted=False
# iter=181 best_before=1313.37 pert=1533.47 imp=1319.78 best_after=1313.37 accepted=False
# iter=182 best_before=1313.37 pert=1389.56 imp=1317.91 best_after=1313.37 accepted=False
# iter=183 best_before=1313.37 pert=1406.42 imp=1313.37 best_after=1313.37 accepted=False
# iter=184 best_before=1313.37 pert=1398.96 imp=1313.37 best_after=1313.37 accepted=False
# iter=185 best_before=1313.37 pert=1513.51 imp=1313.37 best_after=1313.37 accepted=False
# iter=186 best_before=1313.37 pert=1489.56 imp=1315.98 best_after=1313.37 accepted=False
# iter=187 best_before=1313.37 pert=1413.93 imp=1313.37 best_after=1313.37 accepted=False
# iter=188 best_before=1313.37 pert=1469.99 imp=1313.37 best_after=1313.37 accepted=False
# iter=189 best_before=1313.37 pert=1398.58 imp=1313.37 best_after=1313.37 accepted=False
# iter=190 best_before=1313.37 pert=1434.73 imp=1313.86 best_after=1313.37 accepted=False
# iter=191 best_before=1313.37 pert=1458.81 imp=1313.37 best_after=1313.37 accepted=False
# iter=192 best_before=1313.37 pert=1431.12 imp=1313.37 best_after=1313.37 accepted=False
# iter=193 best_before=1313.37 pert=1445.04 imp=1313.37 best_after=1313.37 accepted=False
# iter=194 best_before=1313.37 pert=1642.79 imp=1322.35 best_after=1313.37 accepted=False
# iter=195 best_before=1313.37 pert=1412.88 imp=1313.37 best_after=1313.37 accepted=False
# iter=196 best_before=1313.37 pert=1566.10 imp=1313.37 best_after=1313.37 accepted=False
# iter=197 best_before=1313.37 pert=1587.01 imp=1318.41 best_after=1313.37 accepted=False
# iter=198 best_before=1313.37 pert=1427.59 imp=1313.37 best_after=1313.37 accepted=False
# iter=199 best_before=1313.37 pert=1370.89 imp=1364.35 best_after=1313.37 accepted=False
# iter=200 best_before=1313.37 pert=1429.33 imp=1317.90 best_after=1313.37 accepted=False
# iter=201 best_before=1313.37 pert=1437.77 imp=1313.37 best_after=1313.37 accepted=False
# iter=202 best_before=1313.37 pert=1491.32 imp=1316.45 best_after=1313.37 accepted=False
# iter=203 best_before=1313.37 pert=1383.75 imp=1313.37 best_after=1313.37 accepted=False
# iter=204 best_before=1313.37 pert=1324.52 imp=1313.38 best_after=1313.37 accepted=False
# iter=205 best_before=1313.37 pert=1331.00 imp=1313.37 best_after=1313.37 accepted=False
# iter=206 best_before=1313.37 pert=1415.53 imp=1313.37 best_after=1313.37 accepted=False
# iter=207 best_before=1313.37 pert=1528.46 imp=1313.37 best_after=1313.37 accepted=False
# iter=208 best_before=1313.37 pert=1404.52 imp=1313.37 best_after=1313.37 accepted=False
# iter=209 best_before=1313.37 pert=1395.14 imp=1313.37 best_after=1313.37 accepted=False
# iter=210 best_before=1313.37 pert=1500.28 imp=1313.37 best_after=1313.37 accepted=False
# iter=211 best_before=1313.37 pert=1419.87 imp=1313.37 best_after=1313.37 accepted=False
# iter=212 best_before=1313.37 pert=1488.26 imp=1313.37 best_after=1313.37 accepted=False
# iter=213 best_before=1313.37 pert=1508.97 imp=1313.37 best_after=1313.37 accepted=False
# iter=214 best_before=1313.37 pert=1487.39 imp=1314.46 best_after=1313.37 accepted=False
# iter=215 best_before=1313.37 pert=1454.85 imp=1327.31 best_after=1313.37 accepted=False
# iter=216 best_before=1313.37 pert=1447.99 imp=1313.37 best_after=1313.37 accepted=False
# iter=217 best_before=1313.37 pert=1407.99 imp=1313.37 best_after=1313.37 accepted=False
# iter=218 best_before=1313.37 pert=1495.95 imp=1313.37 best_after=1313.37 accepted=False
# iter=219 best_before=1313.37 pert=1435.24 imp=1313.37 best_after=1313.37 accepted=False
# iter=220 best_before=1313.37 pert=1481.66 imp=1318.41 best_after=1313.37 accepted=False
# iter=221 best_before=1313.37 pert=1388.81 imp=1317.63 best_after=1313.37 accepted=False
# iter=222 best_before=1313.37 pert=1528.40 imp=1321.03 best_after=1313.37 accepted=False
# iter=223 best_before=1313.37 pert=1501.04 imp=1313.37 best_after=1313.37 accepted=False
# iter=224 best_before=1313.37 pert=1404.81 imp=1314.46 best_after=1313.37 accepted=False
# iter=225 best_before=1313.37 pert=1495.66 imp=1313.37 best_after=1313.37 accepted=False
# iter=226 best_before=1313.37 pert=1375.40 imp=1313.37 best_after=1313.37 accepted=False
# iter=227 best_before=1313.37 pert=1359.85 imp=1313.37 best_after=1313.37 accepted=False
# iter=228 best_before=1313.37 pert=1408.07 imp=1313.37 best_after=1313.37 accepted=False
# iter=229 best_before=1313.37 pert=1469.65 imp=1319.78 best_after=1313.37 accepted=False
# iter=230 best_before=1313.37 pert=1456.85 imp=1313.37 best_after=1313.37 accepted=False
# iter=231 best_before=1313.37 pert=1640.80 imp=1314.27 best_after=1313.37 accepted=False
# iter=232 best_before=1313.37 pert=1519.54 imp=1313.38 best_after=1313.37 accepted=False
# iter=233 best_before=1313.37 pert=1410.78 imp=1313.37 best_after=1313.37 accepted=False
# iter=234 best_before=1313.37 pert=1469.12 imp=1317.64 best_after=1313.37 accepted=False
# iter=235 best_before=1313.37 pert=1421.57 imp=1313.37 best_after=1313.37 accepted=False
# iter=236 best_before=1313.37 pert=1562.35 imp=1313.37 best_after=1313.37 accepted=False
# iter=237 best_before=1313.37 pert=1523.23 imp=1313.78 best_after=1313.37 accepted=False
# iter=238 best_before=1313.37 pert=1385.64 imp=1313.77 best_after=1313.37 accepted=False
# iter=239 best_before=1313.37 pert=1415.07 imp=1313.37 best_after=1313.37 accepted=False
# iter=240 best_before=1313.37 pert=1444.08 imp=1316.45 best_after=1313.37 accepted=False
# iter=241 best_before=1313.37 pert=1500.70 imp=1313.37 best_after=1313.37 accepted=False
# iter=242 best_before=1313.37 pert=1471.88 imp=1313.78 best_after=1313.37 accepted=False
# iter=243 best_before=1313.37 pert=1480.54 imp=1313.37 best_after=1313.37 accepted=False
# iter=244 best_before=1313.37 pert=1481.51 imp=1319.32 best_after=1313.37 accepted=False
# iter=245 best_before=1313.37 pert=1526.02 imp=1352.62 best_after=1313.37 accepted=False
# iter=246 best_before=1313.37 pert=1495.48 imp=1317.63 best_after=1313.37 accepted=False
# iter=247 best_before=1313.37 pert=1379.45 imp=1313.37 best_after=1313.37 accepted=False
# iter=248 best_before=1313.37 pert=1360.89 imp=1314.58 best_after=1313.37 accepted=False
# iter=249 best_before=1313.37 pert=1374.00 imp=1313.37 best_after=1313.37 accepted=False
# iter=250 best_before=1313.37 pert=1436.94 imp=1313.37 best_after=1313.37 accepted=False
# iter=251 best_before=1313.37 pert=1450.41 imp=1315.84 best_after=1313.37 accepted=False
# iter=252 best_before=1313.37 pert=1442.41 imp=1313.37 best_after=1313.37 accepted=False
# iter=253 best_before=1313.37 pert=1442.30 imp=1313.37 best_after=1313.37 accepted=False
# iter=254 best_before=1313.37 pert=1430.48 imp=1313.37 best_after=1313.37 accepted=False
# iter=255 best_before=1313.37 pert=1436.11 imp=1326.98 best_after=1313.37 accepted=False
# iter=256 best_before=1313.37 pert=1420.88 imp=1315.27 best_after=1313.37 accepted=False
# iter=257 best_before=1313.37 pert=1483.34 imp=1323.20 best_after=1313.37 accepted=False
# iter=258 best_before=1313.37 pert=1455.07 imp=1313.37 best_after=1313.37 accepted=False
# iter=259 best_before=1313.37 pert=1490.42 imp=1320.37 best_after=1313.37 accepted=False
# iter=260 best_before=1313.37 pert=1388.09 imp=1315.68 best_after=1313.37 accepted=False
# iter=261 best_before=1313.37 pert=1415.70 imp=1313.37 best_after=1313.37 accepted=False
# iter=262 best_before=1313.37 pert=1465.94 imp=1313.37 best_after=1313.37 accepted=False
# iter=263 best_before=1313.37 pert=1473.75 imp=1317.66 best_after=1313.37 accepted=False
# iter=264 best_before=1313.37 pert=1485.16 imp=1313.37 best_after=1313.37 accepted=False
# iter=265 best_before=1313.37 pert=1501.26 imp=1324.01 best_after=1313.37 accepted=False
# iter=266 best_before=1313.37 pert=1469.70 imp=1313.37 best_after=1313.37 accepted=False
# iter=267 best_before=1313.37 pert=1454.74 imp=1313.38 best_after=1313.37 accepted=False
# iter=268 best_before=1313.37 pert=1390.99 imp=1313.37 best_after=1313.37 accepted=False
# iter=269 best_before=1313.37 pert=1498.41 imp=1313.37 best_after=1313.37 accepted=False
# iter=270 best_before=1313.37 pert=1525.83 imp=1313.37 best_after=1313.37 accepted=False
# iter=271 best_before=1313.37 pert=1356.19 imp=1317.63 best_after=1313.37 accepted=False
# iter=272 best_before=1313.37 pert=1351.90 imp=1313.38 best_after=1313.37 accepted=False
# iter=273 best_before=1313.37 pert=1463.29 imp=1317.66 best_after=1313.37 accepted=False
# iter=274 best_before=1313.37 pert=1470.14 imp=1323.09 best_after=1313.37 accepted=False
# iter=275 best_before=1313.37 pert=1410.51 imp=1313.86 best_after=1313.37 accepted=False
# iter=276 best_before=1313.37 pert=1495.63 imp=1316.45 best_after=1313.37 accepted=False
# iter=277 best_before=1313.37 pert=1489.50 imp=1313.37 best_after=1313.37 accepted=False
# iter=278 best_before=1313.37 pert=1327.14 imp=1313.37 best_after=1313.37 accepted=False
# iter=279 best_before=1313.37 pert=1481.00 imp=1313.37 best_after=1313.37 accepted=False
# iter=280 best_before=1313.37 pert=1360.31 imp=1313.37 best_after=1313.37 accepted=False
# iter=281 best_before=1313.37 pert=1430.55 imp=1313.37 best_after=1313.37 accepted=False
# iter=282 best_before=1313.37 pert=1489.83 imp=1313.37 best_after=1313.37 accepted=False
# iter=283 best_before=1313.37 pert=1432.77 imp=1314.58 best_after=1313.37 accepted=False
# iter=284 best_before=1313.37 pert=1414.61 imp=1309.82 best_after=1309.82 accepted=True
# iter=285 best_before=1309.82 pert=1435.79 imp=1309.82 best_after=1309.82 accepted=False
# iter=286 best_before=1309.82 pert=1428.87 imp=1309.82 best_after=1309.82 accepted=False
# iter=287 best_before=1309.82 pert=1453.33 imp=1310.92 best_after=1309.82 accepted=False
# iter=288 best_before=1309.82 pert=1478.44 imp=1309.82 best_after=1309.82 accepted=False
# iter=289 best_before=1309.82 pert=1451.45 imp=1325.22 best_after=1309.82 accepted=False
# iter=290 best_before=1309.82 pert=1461.39 imp=1314.37 best_after=1309.82 accepted=False
# iter=291 best_before=1309.82 pert=1394.69 imp=1312.90 best_after=1309.82 accepted=False
# iter=292 best_before=1309.82 pert=1592.87 imp=1309.82 best_after=1309.82 accepted=False
# iter=293 best_before=1309.82 pert=1403.77 imp=1312.21 best_after=1309.82 accepted=False
# iter=294 best_before=1309.82 pert=1389.43 imp=1309.82 best_after=1309.82 accepted=False
# iter=295 best_before=1309.82 pert=1370.89 imp=1309.82 best_after=1309.82 accepted=False
# iter=296 best_before=1309.82 pert=1428.54 imp=1309.82 best_after=1309.82 accepted=False
# iter=297 best_before=1309.82 pert=1639.24 imp=1318.97 best_after=1309.82 accepted=False
# iter=298 best_before=1309.82 pert=1419.77 imp=1314.09 best_after=1309.82 accepted=False
# iter=299 best_before=1309.82 pert=1507.36 imp=1314.90 best_after=1309.82 accepted=False
# iter=300 best_before=1309.82 pert=1475.49 imp=1309.82 best_after=1309.82 accepted=False
# iter=301 best_before=1309.82 pert=1506.19 imp=1309.82 best_after=1309.82 accepted=False
# iter=302 best_before=1309.82 pert=1460.03 imp=1319.11 best_after=1309.82 accepted=False
# iter=303 best_before=1309.82 pert=1425.36 imp=1309.83 best_after=1309.82 accepted=False
# iter=304 best_before=1309.82 pert=1464.96 imp=1323.44 best_after=1309.82 accepted=False
# iter=305 best_before=1309.82 pert=1419.01 imp=1314.09 best_after=1309.82 accepted=False
# iter=306 best_before=1309.82 pert=1446.83 imp=1309.99 best_after=1309.82 accepted=False
# iter=307 best_before=1309.82 pert=1454.76 imp=1339.42 best_after=1309.82 accepted=False
# iter=308 best_before=1309.82 pert=1398.43 imp=1309.82 best_after=1309.82 accepted=False
# iter=309 best_before=1309.82 pert=1472.16 imp=1310.32 best_after=1309.82 accepted=False
# iter=310 best_before=1309.82 pert=1444.88 imp=1309.82 best_after=1309.82 accepted=False
# iter=311 best_before=1309.82 pert=1515.72 imp=1309.82 best_after=1309.82 accepted=False
# iter=312 best_before=1309.82 pert=1428.54 imp=1314.09 best_after=1309.82 accepted=False
# iter=313 best_before=1309.82 pert=1524.33 imp=1309.82 best_after=1309.82 accepted=False
# iter=314 best_before=1309.82 pert=1572.26 imp=1309.82 best_after=1309.82 accepted=False
# iter=315 best_before=1309.82 pert=1463.33 imp=1323.20 best_after=1309.82 accepted=False
# iter=316 best_before=1309.82 pert=1430.65 imp=1309.82 best_after=1309.82 accepted=False
# iter=317 best_before=1309.82 pert=1393.01 imp=1309.82 best_after=1309.82 accepted=False
# iter=318 best_before=1309.82 pert=1420.69 imp=1309.82 best_after=1309.82 accepted=False
# iter=319 best_before=1309.82 pert=1448.56 imp=1314.09 best_after=1309.82 accepted=False
# iter=320 best_before=1309.82 pert=1423.88 imp=1312.90 best_after=1309.82 accepted=False
# iter=321 best_before=1309.82 pert=1494.14 imp=1310.23 best_after=1309.82 accepted=False
# iter=322 best_before=1309.82 pert=1403.97 imp=1314.37 best_after=1309.82 accepted=False
# iter=323 best_before=1309.82 pert=1476.03 imp=1309.82 best_after=1309.82 accepted=False
# iter=324 best_before=1309.82 pert=1481.45 imp=1316.27 best_after=1309.82 accepted=False
# iter=325 best_before=1309.82 pert=1529.00 imp=1354.11 best_after=1309.82 accepted=False
# iter=326 best_before=1309.82 pert=1319.76 imp=1310.92 best_after=1309.82 accepted=False
# iter=327 best_before=1309.82 pert=1469.20 imp=1314.86 best_after=1309.82 accepted=False
# iter=328 best_before=1309.82 pert=1472.49 imp=1309.82 best_after=1309.82 accepted=False
# iter=329 best_before=1309.82 pert=1428.60 imp=1312.90 best_after=1309.82 accepted=False
# iter=330 best_before=1309.82 pert=1503.86 imp=1312.43 best_after=1309.82 accepted=False
# iter=331 best_before=1309.82 pert=1371.01 imp=1312.45 best_after=1309.82 accepted=False
# iter=332 best_before=1309.82 pert=1489.76 imp=1309.83 best_after=1309.82 accepted=False
# iter=333 best_before=1309.82 pert=1536.48 imp=1309.82 best_after=1309.82 accepted=False
# iter=334 best_before=1309.82 pert=1442.81 imp=1312.58 best_after=1309.82 accepted=False
# iter=335 best_before=1309.82 pert=1461.67 imp=1323.40 best_after=1309.82 accepted=False
# iter=336 best_before=1309.82 pert=1455.97 imp=1309.82 best_after=1309.82 accepted=False
# iter=337 best_before=1309.82 pert=1364.66 imp=1310.92 best_after=1309.82 accepted=False
# iter=338 best_before=1309.82 pert=1447.41 imp=1324.27 best_after=1309.82 accepted=False
# iter=339 best_before=1309.82 pert=1543.09 imp=1309.82 best_after=1309.82 accepted=False
# iter=340 best_before=1309.82 pert=1447.55 imp=1316.24 best_after=1309.82 accepted=False
# iter=341 best_before=1309.82 pert=1480.30 imp=1309.83 best_after=1309.82 accepted=False
# iter=342 best_before=1309.82 pert=1450.60 imp=1309.82 best_after=1309.82 accepted=False
# iter=343 best_before=1309.82 pert=1394.75 imp=1310.32 best_after=1309.82 accepted=False
# iter=344 best_before=1309.82 pert=1392.31 imp=1309.82 best_after=1309.82 accepted=False
# iter=345 best_before=1309.82 pert=1395.22 imp=1309.82 best_after=1309.82 accepted=False
# iter=346 best_before=1309.82 pert=1446.73 imp=1309.83 best_after=1309.82 accepted=False
# iter=347 best_before=1309.82 pert=1406.81 imp=1312.45 best_after=1309.82 accepted=False
# iter=348 best_before=1309.82 pert=1493.70 imp=1309.82 best_after=1309.82 accepted=False
# iter=349 best_before=1309.82 pert=1446.92 imp=1310.23 best_after=1309.82 accepted=False
# iter=350 best_before=1309.82 pert=1436.66 imp=1309.82 best_after=1309.82 accepted=False
# iter=351 best_before=1309.82 pert=1355.14 imp=1309.82 best_after=1309.82 accepted=False
# iter=352 best_before=1309.82 pert=1438.76 imp=1309.82 best_after=1309.82 accepted=False
# iter=353 best_before=1309.82 pert=1487.56 imp=1318.66 best_after=1309.82 accepted=False
# iter=354 best_before=1309.82 pert=1395.85 imp=1309.82 best_after=1309.82 accepted=False
# iter=355 best_before=1309.82 pert=1476.21 imp=1309.82 best_after=1309.82 accepted=False
# iter=356 best_before=1309.82 pert=1458.15 imp=1310.92 best_after=1309.82 accepted=False
# iter=357 best_before=1309.82 pert=1410.08 imp=1323.62 best_after=1309.82 accepted=False
# iter=358 best_before=1309.82 pert=1402.84 imp=1309.82 best_after=1309.82 accepted=False
# iter=359 best_before=1309.82 pert=1409.00 imp=1319.02 best_after=1309.82 accepted=False
# iter=360 best_before=1309.82 pert=1455.28 imp=1316.24 best_after=1309.82 accepted=False
# iter=361 best_before=1309.82 pert=1393.80 imp=1317.39 best_after=1309.82 accepted=False
# iter=362 best_before=1309.82 pert=1477.90 imp=1309.82 best_after=1309.82 accepted=False
# iter=363 best_before=1309.82 pert=1361.25 imp=1309.82 best_after=1309.82 accepted=False
# iter=364 best_before=1309.82 pert=1428.58 imp=1326.91 best_after=1309.82 accepted=False
# iter=365 best_before=1309.82 pert=1480.21 imp=1309.82 best_after=1309.82 accepted=False
# iter=366 best_before=1309.82 pert=1506.29 imp=1309.83 best_after=1309.82 accepted=False
# iter=367 best_before=1309.82 pert=1441.56 imp=1310.92 best_after=1309.82 accepted=False
# iter=368 best_before=1309.82 pert=1445.06 imp=1309.82 best_after=1309.82 accepted=False
# iter=369 best_before=1309.82 pert=1453.02 imp=1309.82 best_after=1309.82 accepted=False
# iter=370 best_before=1309.82 pert=1536.98 imp=1309.82 best_after=1309.82 accepted=False
# iter=371 best_before=1309.82 pert=1479.59 imp=1309.82 best_after=1309.82 accepted=False
# iter=372 best_before=1309.82 pert=1462.07 imp=1309.82 best_after=1309.82 accepted=False
# iter=373 best_before=1309.82 pert=1461.87 imp=1309.82 best_after=1309.82 accepted=False
# iter=374 best_before=1309.82 pert=1523.35 imp=1323.65 best_after=1309.82 accepted=False
# iter=375 best_before=1309.82 pert=1460.65 imp=1310.39 best_after=1309.82 accepted=False
# iter=376 best_before=1309.82 pert=1448.24 imp=1316.24 best_after=1309.82 accepted=False
# iter=377 best_before=1309.82 pert=1391.12 imp=1309.82 best_after=1309.82 accepted=False
# iter=378 best_before=1309.82 pert=1380.04 imp=1309.82 best_after=1309.82 accepted=False
# iter=379 best_before=1309.82 pert=1483.66 imp=1332.03 best_after=1309.82 accepted=False
# iter=380 best_before=1309.82 pert=1422.37 imp=1309.82 best_after=1309.82 accepted=False
# iter=381 best_before=1309.82 pert=1466.50 imp=1326.38 best_after=1309.82 accepted=False
# iter=382 best_before=1309.82 pert=1421.83 imp=1318.66 best_after=1309.82 accepted=False
# iter=383 best_before=1309.82 pert=1501.78 imp=1312.90 best_after=1309.82 accepted=False
# iter=384 best_before=1309.82 pert=1582.35 imp=1310.32 best_after=1309.82 accepted=False
# iter=385 best_before=1309.82 pert=1452.36 imp=1309.82 best_after=1309.82 accepted=False
# iter=386 best_before=1309.82 pert=1483.52 imp=1309.45 best_after=1309.45 accepted=True
# iter=387 best_before=1309.45 pert=1483.47 imp=1343.40 best_after=1309.45 accepted=False
# iter=388 best_before=1309.45 pert=1403.46 imp=1313.71 best_after=1309.45 accepted=False
# iter=389 best_before=1309.45 pert=1376.11 imp=1309.45 best_after=1309.45 accepted=False
# iter=390 best_before=1309.45 pert=1376.83 imp=1309.45 best_after=1309.45 accepted=False
# iter=391 best_before=1309.45 pert=1399.28 imp=1309.45 best_after=1309.45 accepted=False
# iter=392 best_before=1309.45 pert=1498.52 imp=1309.45 best_after=1309.45 accepted=False
# iter=393 best_before=1309.45 pert=1369.95 imp=1310.54 best_after=1309.45 accepted=False
# iter=394 best_before=1309.45 pert=1479.52 imp=1309.45 best_after=1309.45 accepted=False
# iter=395 best_before=1309.45 pert=1505.53 imp=1310.54 best_after=1309.45 accepted=False
# iter=396 best_before=1309.45 pert=1422.11 imp=1309.86 best_after=1309.45 accepted=False
# iter=397 best_before=1309.45 pert=1416.68 imp=1312.06 best_after=1309.45 accepted=False
# iter=398 best_before=1309.45 pert=1422.72 imp=1309.45 best_after=1309.45 accepted=False
# iter=399 best_before=1309.45 pert=1464.92 imp=1309.45 best_after=1309.45 accepted=False
# iter=400 best_before=1309.45 pert=1414.14 imp=1309.45 best_after=1309.45 accepted=False
# iter=401 best_before=1309.45 pert=1407.84 imp=1309.45 best_after=1309.45 accepted=False
# iter=402 best_before=1309.45 pert=1544.69 imp=1312.53 best_after=1309.45 accepted=False
# iter=403 best_before=1309.45 pert=1646.06 imp=1313.74 best_after=1309.45 accepted=False
# iter=404 best_before=1309.45 pert=1424.60 imp=1309.45 best_after=1309.45 accepted=False
# iter=405 best_before=1309.45 pert=1396.81 imp=1309.45 best_after=1309.45 accepted=False
# iter=406 best_before=1309.45 pert=1491.16 imp=1309.45 best_after=1309.45 accepted=False
# iter=407 best_before=1309.45 pert=1522.89 imp=1314.49 best_after=1309.45 accepted=False
# iter=408 best_before=1309.45 pert=1450.08 imp=1313.71 best_after=1309.45 accepted=False
# iter=409 best_before=1309.45 pert=1374.93 imp=1309.45 best_after=1309.45 accepted=False
# iter=410 best_before=1309.45 pert=1407.64 imp=1318.14 best_after=1309.45 accepted=False
# iter=411 best_before=1309.45 pert=1502.34 imp=1312.20 best_after=1309.45 accepted=False
# iter=412 best_before=1309.45 pert=1398.70 imp=1309.45 best_after=1309.45 accepted=False
# iter=413 best_before=1309.45 pert=1445.77 imp=1309.45 best_after=1309.45 accepted=False
# iter=414 best_before=1309.45 pert=1453.40 imp=1313.71 best_after=1309.45 accepted=False
# iter=415 best_before=1309.45 pert=1480.58 imp=1312.53 best_after=1309.45 accepted=False
# iter=416 best_before=1309.45 pert=1497.04 imp=1351.97 best_after=1309.45 accepted=False
# iter=417 best_before=1309.45 pert=1489.15 imp=1309.45 best_after=1309.45 accepted=False
# iter=418 best_before=1309.45 pert=1467.38 imp=1320.16 best_after=1309.45 accepted=False
# iter=419 best_before=1309.45 pert=1390.63 imp=1309.45 best_after=1309.45 accepted=False
# iter=420 best_before=1309.45 pert=1372.21 imp=1309.45 best_after=1309.45 accepted=False
# iter=421 best_before=1309.45 pert=1416.30 imp=1309.86 best_after=1309.45 accepted=False
# iter=422 best_before=1309.45 pert=1502.65 imp=1323.09 best_after=1309.45 accepted=False
# iter=423 best_before=1309.45 pert=1499.43 imp=1309.45 best_after=1309.45 accepted=False
# iter=424 best_before=1309.45 pert=1429.69 imp=1309.45 best_after=1309.45 accepted=False
# iter=425 best_before=1309.45 pert=1453.50 imp=1309.45 best_after=1309.45 accepted=False
# iter=426 best_before=1309.45 pert=1474.96 imp=1309.45 best_after=1309.45 accepted=False
# iter=427 best_before=1309.45 pert=1519.16 imp=1309.45 best_after=1309.45 accepted=False
# iter=428 best_before=1309.45 pert=1410.00 imp=1317.99 best_after=1309.45 accepted=False
# iter=429 best_before=1309.45 pert=1457.08 imp=1309.45 best_after=1309.45 accepted=False
# iter=430 best_before=1309.45 pert=1493.88 imp=1314.15 best_after=1309.45 accepted=False
# iter=431 best_before=1309.45 pert=1487.38 imp=1323.03 best_after=1309.45 accepted=False
# iter=432 best_before=1309.45 pert=1441.68 imp=1309.45 best_after=1309.45 accepted=False
# iter=433 best_before=1309.45 pert=1443.33 imp=1309.45 best_after=1309.45 accepted=False
# iter=434 best_before=1309.45 pert=1459.25 imp=1309.45 best_after=1309.45 accepted=False
# iter=435 best_before=1309.45 pert=1495.61 imp=1309.45 best_after=1309.45 accepted=False
# iter=436 best_before=1309.45 pert=1605.40 imp=1323.16 best_after=1309.45 accepted=False
# iter=437 best_before=1309.45 pert=1484.18 imp=1309.45 best_after=1309.45 accepted=False
# iter=438 best_before=1309.45 pert=1441.30 imp=1309.45 best_after=1309.45 accepted=False
# iter=439 best_before=1309.45 pert=1437.12 imp=1313.72 best_after=1309.45 accepted=False
# iter=440 best_before=1309.45 pert=1322.07 imp=1309.45 best_after=1309.45 accepted=False
# iter=441 best_before=1309.45 pert=1565.81 imp=1312.53 best_after=1309.45 accepted=False
# iter=442 best_before=1309.45 pert=1469.05 imp=1319.22 best_after=1309.45 accepted=False
# iter=443 best_before=1309.45 pert=1471.59 imp=1309.45 best_after=1309.45 accepted=False
# iter=444 best_before=1309.45 pert=1559.58 imp=1310.20 best_after=1309.45 accepted=False
# iter=445 best_before=1309.45 pert=1432.15 imp=1309.45 best_after=1309.45 accepted=False
# iter=446 best_before=1309.45 pert=1458.43 imp=1318.73 best_after=1309.45 accepted=False
# iter=447 best_before=1309.45 pert=1505.28 imp=1313.74 best_after=1309.45 accepted=False
# iter=448 best_before=1309.45 pert=1343.11 imp=1313.74 best_after=1309.45 accepted=False
# iter=449 best_before=1309.45 pert=1414.54 imp=1309.45 best_after=1309.45 accepted=False
# iter=450 best_before=1309.45 pert=1488.05 imp=1309.45 best_after=1309.45 accepted=False
# iter=451 best_before=1309.45 pert=1454.83 imp=1309.94 best_after=1309.45 accepted=False
# iter=452 best_before=1309.45 pert=1492.36 imp=1309.45 best_after=1309.45 accepted=False
# iter=453 best_before=1309.45 pert=1405.18 imp=1309.45 best_after=1309.45 accepted=False
# iter=454 best_before=1309.45 pert=1375.71 imp=1309.45 best_after=1309.45 accepted=False
# iter=455 best_before=1309.45 pert=1447.26 imp=1309.86 best_after=1309.45 accepted=False
# iter=456 best_before=1309.45 pert=1456.99 imp=1309.82 best_after=1309.45 accepted=False
# iter=457 best_before=1309.45 pert=1474.82 imp=1312.53 best_after=1309.45 accepted=False
# iter=458 best_before=1309.45 pert=1443.50 imp=1309.45 best_after=1309.45 accepted=False
# iter=459 best_before=1309.45 pert=1430.96 imp=1313.71 best_after=1309.45 accepted=False
# iter=460 best_before=1309.45 pert=1401.79 imp=1319.47 best_after=1309.45 accepted=False
# iter=461 best_before=1309.45 pert=1375.31 imp=1309.45 best_after=1309.45 accepted=False
# iter=462 best_before=1309.45 pert=1367.57 imp=1309.45 best_after=1309.45 accepted=False
# iter=463 best_before=1309.45 pert=1491.05 imp=1312.06 best_after=1309.45 accepted=False
# iter=464 best_before=1309.45 pert=1536.61 imp=1309.45 best_after=1309.45 accepted=False
# iter=465 best_before=1309.45 pert=1409.11 imp=1309.86 best_after=1309.45 accepted=False
# iter=466 best_before=1309.45 pert=1442.38 imp=1309.45 best_after=1309.45 accepted=False
# iter=467 best_before=1309.45 pert=1609.81 imp=1320.66 best_after=1309.45 accepted=False
# iter=468 best_before=1309.45 pert=1418.17 imp=1309.45 best_after=1309.45 accepted=False
# iter=469 best_before=1309.45 pert=1390.87 imp=1309.45 best_after=1309.45 accepted=False
# iter=470 best_before=1309.45 pert=1369.13 imp=1309.45 best_after=1309.45 accepted=False
# iter=471 best_before=1309.45 pert=1343.98 imp=1310.54 best_after=1309.45 accepted=False
# iter=472 best_before=1309.45 pert=1555.58 imp=1309.45 best_after=1309.45 accepted=False
# iter=473 best_before=1309.45 pert=1517.08 imp=1325.58 best_after=1309.45 accepted=False
# iter=474 best_before=1309.45 pert=1501.54 imp=1315.96 best_after=1309.45 accepted=False
# iter=475 best_before=1309.45 pert=1580.13 imp=1318.43 best_after=1309.45 accepted=False
# iter=476 best_before=1309.45 pert=1372.32 imp=1309.45 best_after=1309.45 accepted=False
# iter=477 best_before=1309.45 pert=1400.09 imp=1313.76 best_after=1309.45 accepted=False
# iter=478 best_before=1309.45 pert=1553.87 imp=1309.45 best_after=1309.45 accepted=False
# iter=479 best_before=1309.45 pert=1530.72 imp=1309.45 best_after=1309.45 accepted=False
# iter=480 best_before=1309.45 pert=1465.34 imp=1309.45 best_after=1309.45 accepted=False
# iter=481 best_before=1309.45 pert=1454.86 imp=1310.86 best_after=1309.45 accepted=False
# iter=482 best_before=1309.45 pert=1319.81 imp=1309.86 best_after=1309.45 accepted=False
# iter=483 best_before=1309.45 pert=1427.84 imp=1309.94 best_after=1309.45 accepted=False
# iter=484 best_before=1309.45 pert=1610.96 imp=1310.58 best_after=1309.45 accepted=False
# iter=485 best_before=1309.45 pert=1410.65 imp=1312.53 best_after=1309.45 accepted=False
# iter=486 best_before=1309.45 pert=1428.20 imp=1309.45 best_after=1309.45 accepted=False
# iter=487 best_before=1309.45 pert=1433.71 imp=1309.45 best_after=1309.45 accepted=False
# iter=488 best_before=1309.45 pert=1451.28 imp=1309.45 best_after=1309.45 accepted=False
# iter=489 best_before=1309.45 pert=1425.95 imp=1313.71 best_after=1309.45 accepted=False
# iter=490 best_before=1309.45 pert=1400.33 imp=1309.45 best_after=1309.45 accepted=False
# iter=491 best_before=1309.45 pert=1493.09 imp=1309.45 best_after=1309.45 accepted=False
# iter=492 best_before=1309.45 pert=1477.39 imp=1310.54 best_after=1309.45 accepted=False
# iter=493 best_before=1309.45 pert=1434.47 imp=1309.45 best_after=1309.45 accepted=False
# iter=494 best_before=1309.45 pert=1397.90 imp=1309.45 best_after=1309.45 accepted=False
# iter=495 best_before=1309.45 pert=1574.08 imp=1313.74 best_after=1309.45 accepted=False
# iter=496 best_before=1309.45 pert=1385.90 imp=1312.06 best_after=1309.45 accepted=False
# iter=497 best_before=1309.45 pert=1435.60 imp=1309.86 best_after=1309.45 accepted=False
# iter=498 best_before=1309.45 pert=1389.64 imp=1309.45 best_after=1309.45 accepted=False
# iter=499 best_before=1309.45 pert=1407.59 imp=1309.45 best_after=1309.45 accepted=False
# iter=500 best_before=1309.45 pert=1601.69 imp=1309.94 best_after=1309.45 accepted=False

# %% [markdown]
# # Adaptive Iterated Lovebird Algorithm

# %%
def perturb_spatial_destroy_repair(route, strength, dist_matrix, node_map):
    """
    AILS 'Heavy' Perturbation: Spatial (Radial) Removal + Noisy Insertion.
    1. Pick a random center node.
    2. Remove 'strength' closest neighbors (Spatial Cluster).
    3. Re-insert them using Noisy Cheapest Insertion.
    """
    n = len(route)
    if n <= 3: return route[:]

    # --- 1. SPATIAL DESTROY ---
    # Target removal amount (capped at 30% to preserve structure)
    num_remove = min(strength, int(n * 0.30))
    if num_remove < 4: num_remove = 4

    # Pick a random center point from the route
    center_node = random.choice(route)
    center_idx = node_map[center_node]

    # Find neighbors in the current route sorted by distance to center
    # (Optimization: In a full solver, we'd pre-calculate neighbor lists, 
    # but for N<1000 this sort is negligible)
    route_nodes = sorted(route, key=lambda x: dist_matrix[center_idx][node_map[x]])
    
    # Select the k closest nodes to remove
    nodes_to_remove = set(route_nodes[:num_remove])
    
    # Construct partial route
    new_route = [node for node in route if node not in nodes_to_remove]
    
    # Nodes to re-insert (shuffle to avoid deterministic bias)
    removed_nodes = list(nodes_to_remove)
    random.shuffle(removed_nodes)

    # --- 2. NOISY REPAIR ---
    for node_to_insert in removed_nodes:
        c_idx = node_map[node_to_insert]
        best_weighted_cost = float('inf')
        best_pos = -1
        
        len_current = len(new_route)
        
        # Try all positions
        for i in range(len_current):
            u = new_route[i]
            v = new_route[(i + 1) % len_current]
            
            u_i = node_map[u]
            v_i = node_map[v]
            
            # Cost increase
            delta = dist_matrix[u_i][c_idx] + dist_matrix[c_idx][v_i] - dist_matrix[u_i][v_i]
            
            # Noise factor (0.8 - 1.2) to break greedy determinism
            noise = random.uniform(0.8, 1.2)
            weighted_cost = delta * noise
            
            if weighted_cost < best_weighted_cost:
                best_weighted_cost = weighted_cost
                best_pos = i + 1
        
        new_route.insert(best_pos, node_to_insert)

    return new_route

def perturb_double_bridge(route):
    """Classic 4-opt kick (Fast & Non-destructive)"""
    n = len(route)
    if n < 8: return route[:]
    
    pos = sorted(random.sample(range(1, n), 3))
    i, j, k = pos
    # A-B-C-D -> A-D-C-B (Crosses two edges)
    return route[:i] + route[k:] + route[j:k] + route[i:j]

# %%
def cheapest_insertion_build(node_list):

    if not node_list:
        return []
    if len(node_list) <= 2:
        return node_list[:]

    # 1. Start with the first node (depot or arbitrary start)
    # Since we want a closed loop, we treat it as a subtour.
    tour = [node_list[0]]
    unvisited = set(node_list[1:])

    # 2. Initialize subtour with the nearest neighbor to the start node
    # to form the first edge (or stick with single node if preferred, 
    # but edges define cost better).
    if unvisited:
        u0_idx = idx[tour[0]]
        # Find node in unvisited closest to tour[0]
        next_node = min(unvisited, key=lambda x: D[u0_idx, idx[x]])
        tour.append(next_node)
        unvisited.remove(next_node)

    # 3. Iteratively insert remaining nodes
    while unvisited:
        best_delta = float('inf')
        best_node = None
        best_pos = -1

        for candidate in unvisited:
            c_idx = idx[candidate]
            
            # Try inserting 'candidate' between every pair (u, v) in current tour
            for i in range(len(tour)):
                u = tour[i]
                v = tour[(i + 1) % len(tour)] # Wrap around for circularity
                
                u_i = idx[u]
                v_i = idx[v]
                
                # Cost of insertion = d(u, c) + d(c, v) - d(u, v)
                delta = D[u_i, c_idx] + D[c_idx, v_i] - D[u_i, v_i]
                
                if delta < best_delta:
                    best_delta = delta
                    best_node = candidate
                    best_pos = i + 1
        
        # Insert the best node found
        if best_node is not None:
            tour.insert(best_pos, best_node)
            unvisited.remove(best_node)
            
    return tour

# %%
def adaptive_iterated_lovebird(
    max_iter=300,
    local_gen=3,
    clusters=None,
    labels=None, nodes=None,
    initial_solution=None,
    seed=None,
    budget_s=None,
    init_mutations=20,
    patience=5
):
    if seed is not None:
        random.seed(seed)

    # --- 1. Initialization ---
    # (Same as before: Construction Phase)
    def _init_solution():
        if clusters: return [r[:] for r in clusters if r]
        lab_arr = np.asarray(labels)
        K = int(lab_arr.max()) + 1
        tmp = {c: [] for c in range(K)}
        for n, l in zip(nodes, lab_arr):
            tmp[int(l)].append(n)
        return [cheapest_insertion_build(tmp[c]) for c in range(K) if tmp[c]]

    current_sol = _init_solution()
    
    t_start = time.perf_counter()
    def time_left():
        return None if budget_s is None else max(0.0, (t_start + budget_s) - time.perf_counter())

    # --- 2. Lovebird Evolution (Initial Polish) ---
    best_sol = [r[:] for r in current_sol]
    best_cost = sum(total_distance(r) for r in best_sol)
    
    ops = [swap_two, flip, interchange, slide]
    
    for _ in range(init_mutations):
        if budget_s and time_left() <= 0: break
        cand = [r[:] for r in best_sol]
        r_idx = random.randrange(len(cand))
        if len(cand[r_idx]) > 3:
            op = random.choice(ops)
            i, j = sorted(random.sample(range(len(cand[r_idx])), 2))
            cand[r_idx] = op(cand[r_idx], i, j)
            c_cost = sum(total_distance(r) for r in cand)
            if c_cost < best_cost:
                best_sol = cand
                best_cost = c_cost

    # Full 2-opt polish before starting AILS
    best_sol, best_cost, _, _ = two_opt_local_search(
        maxLoop=local_gen*2, clusters=best_sol, time_budget=time_left()
    )
    
    history = [best_cost]
    
    # --- 3. Hybrid AILS Main Loop ---
    current_sol = [r[:] for r in best_sol]
    current_cost = best_cost
    
    stagnation_counter = 0
    perturbation_level = 0 # 0=Light, 1=Medium, 2+=Heavy
    
    for it in range(max_iter):
        if budget_s and time_left() <= 0.05: break

        # --- A. Adaptive Perturbation Selection ---
        perturbed_sol = []
        
        # Strategy Switcher:
        # Level 0-2 (Low Stagnation): Use Double Bridge (Fast, O(1))
        # Level 3+  (High Stagnation): Use Spatial Destroy/Repair (Powerful, O(N^2))
        
        use_heavy_perturbation = (perturbation_level >= 3)
        
        for r in current_sol:
            if len(r) > 4:
                if not use_heavy_perturbation:
                    # LIGHT KICK: Double Bridge
                    # If level is 1 or 2, apply it 1 or 2 times for stronger shake
                    repeats = max(1, perturbation_level)
                    r_new = r[:]
                    for _ in range(repeats):
                        r_new = perturb_double_bridge(r_new)
                    perturbed_sol.append(r_new)
                else:
                    # HEAVY KICK: Spatial Destroy & Repair
                    # Scale strength: starts at 8 nodes, increases by 4 per level
                    strength = 8 + (perturbation_level - 3) * 4
                    r_new = perturb_spatial_destroy_repair(r, strength, D, idx)
                    perturbed_sol.append(r_new)
            else:
                perturbed_sol.append(r[:])

        # --- B. Local Search ---
        improved_sol, improved_cost, _, _ = two_opt_local_search(
            maxLoop=local_gen, 
            clusters=perturbed_sol,
            time_budget=time_left()
        )

        # --- C. Acceptance & Adaptation ---
        if improved_cost < current_cost - 1e-6:
            # Improvement found
            current_sol = improved_sol
            current_cost = improved_cost
            
            # Global Improvement?
            if current_cost < best_cost - 1e-6:
                best_sol = [r[:] for r in current_sol]
                best_cost = current_cost
                # Full Reset: We found a new best, go back to gentle search
                stagnation_counter = 0
                perturbation_level = 0
            else:
                # Local Improvement: Good, but keep momentum
                stagnation_counter = 0
                # Don't reset level to 0 immediately, maybe just step back
                perturbation_level = max(0, perturbation_level - 1)
                
        else:
            # Stagnation
            stagnation_counter += 1
            
            # Increase intensity if stuck
            if stagnation_counter >= patience:
                perturbation_level += 1
                stagnation_counter = 0 # Reset counter for the new level
                
                # Safety Reset: If we have destroyed too much without luck, 
                # restart from global best to prevent getting lost in bad space
                if perturbation_level > 6:
                    current_sol = [r[:] for r in best_sol]
                    current_cost = best_cost
                    perturbation_level = 0

        history.append(best_cost)

    return best_sol, best_cost, history

# %%
best_sol_ail, best_cost_ail, hist_ail = adaptive_iterated_lovebird(
    max_iter=300, local_gen=3, patience=3,
    labels=labels, nodes=nodes, budget_s=None
)

# ringkasan hasil
per_costs_ail = [total_distance(r) for r in best_sol_ail]
print("Biaya per kluster:", per_costs_ail)
print("Total biaya:", sum(per_costs_ail))
for i, r in enumerate(best_sol_ail, 1):
    print(f"Rute kluster {i} (|r|={len(r)}): {r}")
# Out:
# Biaya per kluster: [733.5442587509533, 574.2730389151801]
# Total biaya: 1307.8172976661335
# Rute kluster 1 (|r|=75): [76, 88, 77, 20, 60, 16, 85, 6, 108, 41, 116, 18, 69, 84, 8, 135, 53, 38, 78, 58, 128, 44, 114, 90, 3, 82, 125, 59, 27, 51, 80, 10, 117, 52, 29, 54, 110, 106, 15, 93, 132, 112, 96, 62, 37, 81, 40, 72, 34, 107, 23, 63, 111, 133, 95, 4, 42, 103, 11, 26, 124, 21, 129, 67, 123, 43, 50, 101, 130, 1, 71, 55, 30, 115, 47]
# Rute kluster 2 (|r|=60): [99, 9, 49, 94, 24, 105, 36, 91, 5, 97, 31, 83, 102, 13, 119, 75, 2, 66, 74, 39, 104, 113, 64, 25, 120, 70, 12, 92, 32, 127, 48, 98, 131, 89, 33, 100, 126, 61, 45, 46, 19, 118, 68, 109, 121, 87, 28, 122, 73, 57, 134, 14, 65, 7, 86, 22, 79, 35, 17, 56]

# %%
# Plot history
plt.figure(figsize=(8,4))
plt.plot(hist_ail, marker='o')
plt.title("Perkembangan Fitness Adaptive Iterated Lovebird Algorithm")
plt.xlabel("Generasi")
plt.ylabel("Total Distance")
plt.grid(True)
plt.show()

# %%
# --- contoh pakai hasil lovebird ---
plot_clustered_routes_matplotlib(
    best_sol_ail,
    show_ids=False,
    title=f"Adaptive Iterated Lovebird Clustered • total cost = {best_cost_ail:.2f}"
)

# %% [markdown]
# ## AILS Debugging

# %%
def adaptive_iterated_lovebird_debug( 
    max_iter=300, 
    local_gen=3, 
    clusters=None,
    labels=None, nodes=None,
    initial_solution=None,
    seed=None,
    budget_s=None,
    init_mutations=20,
    patience=3,
    max_level=5,
    debug=False,          # NEW: flag debug
):
    if seed is not None:
        random.seed(seed)

    # --- siapkan solusi awal yang menghormati kluster ---
    def _init_solution_from_inputs():
        if clusters is not None:
            cur = [r[:] for r in clusters if len(r) > 0]
            return cur if cur else [[]]

        elif (labels is not None) and (nodes is not None):
            lab_arr = np.asarray(labels)
            K = int(lab_arr.max()) + 1 if lab_arr.size > 0 else 0
            tmp = {c: [] for c in range(K)}
            for n, l in zip(nodes, lab_arr):
                tmp[int(l)].append(n)

            # --- RANDOM urutan dalam tiap kluster ---
            cur = []
            for c in range(K):
                if tmp[c]:
                    r = tmp[c][:]        # copy node2 dalam cluster c
                    random.shuffle(r)    # acak urutan dalam kluster
                    cur.append(r)

            return cur if cur else [[]]

        elif initial_solution is not None:
            return [r[:] for r in initial_solution if len(r) > 0] or [[]]

        else:
            ids_copy = ids[:]
            random.shuffle(ids_copy)
            return [ids_copy]  # single-route fallback

    ls = two_opt_local_search

    # --- time budget helper (opsional) ---
    SAFETY   = 0.05
    t_start  = time.perf_counter()
    deadline = (t_start + budget_s) if (budget_s is not None) else None

    def time_left():
        return None if deadline is None else max(0.0, deadline - time.perf_counter())

    if debug:
        print("=== AILS START ===")
        print(f"max_iter={max_iter}, local_gen={local_gen}, "
              f"init_mutations={init_mutations}, patience={patience}, max_level={max_level}")
        if budget_s is not None:
            print(f"global_time_budget={budget_s} s")

    # =========================
    # 1) Solusi awal
    # =========================
    start_solution = _init_solution_from_inputs()
    if debug:
        init_cost = sum(total_distance(r) for r in start_solution)
        print(f"[INIT] initial solution cost = {init_cost:.4f}")

    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in start_solution]
        best_cost = sum(total_distance(r) for r in best_sol)
        if debug:
            print("[EARLY RETURN] kehabisan waktu sebelum mutasi awal")
        return best_sol, float(best_cost), [float(best_cost)]

    # =========================
    # 2) FASE MUTASI LOVEBIRD (eksplorasi awal)
    # =========================
    best_seed = [r[:] for r in start_solution]
    best_seed_cost = sum(total_distance(r) for r in best_seed)

    lovebird_ops = [swap_two, flip, interchange, slide, guided_swap, scramble]

    if debug:
        t_mut_start = time.perf_counter()

    for m in range(1, init_mutations + 1):
        rem = time_left()
        if rem is not None and rem <= SAFETY:
            if debug:
                print(f"[MUT] stop di m={m} karena time limit")
            break

        cand = [r[:] for r in start_solution]

        route_indices = [i for i, r in enumerate(cand) if len(r) >= 2]
        if not route_indices:
            if debug:
                print("[MUT] tidak ada rute yang bisa dimutasi")
            break

        v = random.choice(route_indices)
        route = cand[v][:]

        op = random.choice(lovebird_ops)

        if op is scramble:
            new_route = scramble(route)
        else:
            L = len(route)
            if L < 2:
                continue
            i, j = sorted(random.sample(range(L), 2))
            new_route = op(route, i, j)

        cand[v] = new_route
        cand_cost = sum(total_distance(r) for r in cand)

        if cand_cost < best_seed_cost - 1e-9:
            best_seed = cand
            best_seed_cost = cand_cost

        if debug and (m % 5 == 0 or m == 1):
            print(f"[MUT] m={m:2d} cand_cost={cand_cost:.2f} "
                  f"best_seed_cost={best_seed_cost:.2f}")

    if debug:
        t_mut_end = time.perf_counter()
        print(f"[MUT] selesai, best_seed_cost={best_seed_cost:.4f}, "
              f"time={(t_mut_end - t_mut_start):.3f}s")

    # =========================
    # 3) LS awal dari best_seed
    # =========================
    rem = time_left()
    if rem is not None and rem <= SAFETY:
        best_sol = [r[:] for r in best_seed]
        best_cost = sum(total_distance(r) for r in best_sol)
        if debug:
            print("[EARLY RETURN] kehabisan waktu sebelum LS awal")
        return best_sol, float(best_cost), [float(best_cost)]

    if debug:
        t_ls0_start = time.perf_counter()

    best_sol, best_cost, hist0, _ = ls(
        maxLoop=local_gen,
        clusters=best_seed,
        time_budget=(rem - SAFETY) if rem is not None else None
    )
    history = [best_cost]

    if debug:
        t_ls0_end = time.perf_counter()
        print(f"[LS0] cost={best_cost:.4f}, "
              f"ls_iters={len(hist0)-1}, time={(t_ls0_end - t_ls0_start):.3f}s")

    # =========================
    # 4) AILS loop: tingkat perturbasi adaptif
    # =========================
    no_improve = 0  # counter stagnasi

    for it in range(1, max_iter + 1):
        rem = time_left()
        if rem is not None and rem <= SAFETY:
            if debug:
                print(f"[LOOP] stop di iter={it} karena time limit (rem={rem:.3f}s)")
            break

        best_before = best_cost
        stagn_before = no_improve

        # === pilih tingkat perturbasi berdasarkan stagnasi ===
        level = 1 + (no_improve // patience)
        if level > max_level:
            level = max_level

        # === perturbasi solusi terbaik sekarang ===
        t_iter_start = time.perf_counter()

        perturbed = [r[:] for r in best_sol]
        for _k in range(level):
            perturbed = double_bridge_multi(perturbed)

        if debug:
            pert_cost = sum(total_distance(r) for r in perturbed)

        rem = time_left()
        if rem is not None and rem <= SAFETY:
            if debug:
                print(f"[LOOP] stop di iter={it} setelah perturbasi (rem={rem:.3f}s)")
            break

        # === local search ===
        imp_sol, imp_cost, imp_hist, _ = ls(
            maxLoop=local_gen,
            clusters=perturbed,
            time_budget=(rem - SAFETY) if rem is not None else None
        )

        accepted = False
        if imp_cost < best_cost - 1e-9:
            best_sol = [r[:] for r in imp_sol]
            best_cost = imp_cost
            no_improve = 0
            accepted = True
        else:
            no_improve += 1

        history.append(best_cost)

        t_iter_end = time.perf_counter()
        iter_time = t_iter_end - t_iter_start

        if debug:
            rem_now = time_left()
            ls_iters = len(imp_hist) - 1
            print(
                f"iter={it:3d} "
                f"lvl={level} "
                f"stag_before={stagn_before:3d} "
                f"best_before={best_before:7.2f} "
                f"pert={pert_cost:7.2f} "
                f"imp={imp_cost:7.2f} "
                f"best_after={best_cost:7.2f} "
                f"acc={str(accepted):5s} "
                f"ls_iters={ls_iters:3d} "
                f"t_iter={iter_time:6.3f}s "
                f"rem={('None' if rem_now is None else f'{rem_now:6.3f}s')}"
            )

    if debug:
        total_time = time.perf_counter() - t_start
        print(f"=== AILS END === best_cost={best_cost:.4f}, total_time={total_time:.3f}s")

    return best_sol, float(best_cost), history

# %%
best_sol_ail, best_cost_ail, hist_ail = adaptive_iterated_lovebird_debug(
    max_iter=300, local_gen=3, patience=3, init_mutations=30,
    labels=labels, nodes=nodes, budget_s=None, debug=True
)
# Out:
# === AILS START ===
# max_iter=300, local_gen=3, init_mutations=30, patience=3, max_level=5
# [INIT] initial solution cost = 7475.9069
# [MUT] m= 1 cand_cost=7470.76 best_seed_cost=7470.76
# [MUT] m= 5 cand_cost=7470.73 best_seed_cost=7470.73
# [MUT] m=10 cand_cost=7804.24 best_seed_cost=7438.80
# [MUT] m=15 cand_cost=8071.94 best_seed_cost=7417.87
# [MUT] m=20 cand_cost=7469.79 best_seed_cost=7417.87
# [MUT] m=25 cand_cost=7361.74 best_seed_cost=7361.74
# [MUT] m=30 cand_cost=7506.22 best_seed_cost=7361.74
# [MUT] selesai, best_seed_cost=7361.7380, time=0.001s
# [LS0] cost=1354.8177, ls_iters=3, time=0.267s
# iter=  1 lvl=1 stag_before=  0 best_before=1354.82 pert=1455.67 imp=1360.42 best_after=1354.82 acc=False ls_iters=  3 t_iter= 0.015s rem=None
# iter=  2 lvl=1 stag_before=  1 best_before=1354.82 pert=1592.34 imp=1355.31 best_after=1354.82 acc=False ls_iters=  3 t_iter= 0.012s rem=None
# iter=  3 lvl=1 stag_before=  2 best_before=1354.82 pert=1417.59 imp=1354.82 best_after=1354.82 acc=False ls_iters=  3 t_iter= 0.012s rem=None
# iter=  4 lvl=2 stag_before=  3 best_before=1354.82 pert=1564.87 imp=1357.58 best_after=1354.82 acc=False ls_iters=  3 t_iter= 0.019s rem=None
# iter=  5 lvl=2 stag_before=  4 best_before=1354.82 pert=1704.83 imp=1350.42 best_after=1350.42 acc=True  ls_iters=  3 t_iter= 0.031s rem=None
# iter=  6 lvl=1 stag_before=  0 best_before=1350.42 pert=1427.20 imp=1350.42 best_after=1350.42 acc=False ls_iters=  3 t_iter= 0.014s rem=None
# iter=  7 lvl=1 stag_before=  1 best_before=1350.42 pert=1452.44 imp=1344.22 best_after=1344.22 acc=True  ls_iters=  3 t_iter= 0.027s rem=None
# iter=  8 lvl=1 stag_before=  0 best_before=1344.22 pert=1523.10 imp=1349.52 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.015s rem=None
# iter=  9 lvl=1 stag_before=  1 best_before=1344.22 pert=1454.13 imp=1344.22 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.037s rem=None
# iter= 10 lvl=1 stag_before=  2 best_before=1344.22 pert=1526.30 imp=1350.76 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.022s rem=None
# iter= 11 lvl=2 stag_before=  3 best_before=1344.22 pert=1528.56 imp=1349.52 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.017s rem=None
# iter= 12 lvl=2 stag_before=  4 best_before=1344.22 pert=1581.93 imp=1350.37 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.018s rem=None
# iter= 13 lvl=2 stag_before=  5 best_before=1344.22 pert=1599.75 imp=1394.69 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.023s rem=None
# iter= 14 lvl=3 stag_before=  6 best_before=1344.22 pert=1690.48 imp=1344.22 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.016s rem=None
# iter= 15 lvl=3 stag_before=  7 best_before=1344.22 pert=1808.99 imp=1344.71 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.029s rem=None
# iter= 16 lvl=3 stag_before=  8 best_before=1344.22 pert=1819.62 imp=1366.73 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.026s rem=None
# iter= 17 lvl=4 stag_before=  9 best_before=1344.22 pert=1998.79 imp=1409.92 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.039s rem=None
# iter= 18 lvl=4 stag_before= 10 best_before=1344.22 pert=1759.41 imp=1350.01 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.025s rem=None
# iter= 19 lvl=4 stag_before= 11 best_before=1344.22 pert=2003.54 imp=1356.35 best_after=1344.22 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter= 20 lvl=5 stag_before= 12 best_before=1344.22 pert=2059.97 imp=1325.16 best_after=1325.16 acc=True  ls_iters=  3 t_iter= 0.057s rem=None
# iter= 21 lvl=1 stag_before=  0 best_before=1325.16 pert=1391.18 imp=1327.80 best_after=1325.16 acc=False ls_iters=  3 t_iter= 0.014s rem=None
# iter= 22 lvl=1 stag_before=  1 best_before=1325.16 pert=1426.28 imp=1332.69 best_after=1325.16 acc=False ls_iters=  3 t_iter= 0.017s rem=None
# iter= 23 lvl=1 stag_before=  2 best_before=1325.16 pert=1335.12 imp=1325.16 best_after=1325.16 acc=False ls_iters=  3 t_iter= 0.014s rem=None
# iter= 24 lvl=2 stag_before=  3 best_before=1325.16 pert=1587.03 imp=1326.06 best_after=1325.16 acc=False ls_iters=  3 t_iter= 0.016s rem=None
# iter= 25 lvl=2 stag_before=  4 best_before=1325.16 pert=1579.84 imp=1332.76 best_after=1325.16 acc=False ls_iters=  3 t_iter= 0.019s rem=None
# iter= 26 lvl=2 stag_before=  5 best_before=1325.16 pert=1782.24 imp=1330.52 best_after=1325.16 acc=False ls_iters=  3 t_iter= 0.041s rem=None
# iter= 27 lvl=3 stag_before=  6 best_before=1325.16 pert=1664.55 imp=1378.89 best_after=1325.16 acc=False ls_iters=  3 t_iter= 0.031s rem=None
# iter= 28 lvl=3 stag_before=  7 best_before=1325.16 pert=2056.79 imp=1324.32 best_after=1324.32 acc=True  ls_iters=  3 t_iter= 0.057s rem=None
# iter= 29 lvl=1 stag_before=  0 best_before=1324.32 pert=1541.04 imp=1336.28 best_after=1324.32 acc=False ls_iters=  3 t_iter= 0.021s rem=None
# iter= 30 lvl=1 stag_before=  1 best_before=1324.32 pert=1468.30 imp=1332.87 best_after=1324.32 acc=False ls_iters=  3 t_iter= 0.024s rem=None
# iter= 31 lvl=1 stag_before=  2 best_before=1324.32 pert=1365.35 imp=1329.31 best_after=1324.32 acc=False ls_iters=  3 t_iter= 0.018s rem=None
# iter= 32 lvl=2 stag_before=  3 best_before=1324.32 pert=1615.00 imp=1331.71 best_after=1324.32 acc=False ls_iters=  3 t_iter= 0.016s rem=None
# iter= 33 lvl=2 stag_before=  4 best_before=1324.32 pert=1645.44 imp=1328.84 best_after=1324.32 acc=False ls_iters=  3 t_iter= 0.026s rem=None
# iter= 34 lvl=2 stag_before=  5 best_before=1324.32 pert=1512.14 imp=1324.26 best_after=1324.26 acc=True  ls_iters=  3 t_iter= 0.027s rem=None
# iter= 35 lvl=1 stag_before=  0 best_before=1324.26 pert=1682.62 imp=1323.77 best_after=1323.77 acc=True  ls_iters=  3 t_iter= 0.013s rem=None
# iter= 36 lvl=1 stag_before=  0 best_before=1323.77 pert=1425.22 imp=1324.26 best_after=1323.77 acc=False ls_iters=  3 t_iter= 0.020s rem=None
# iter= 37 lvl=1 stag_before=  1 best_before=1323.77 pert=1441.38 imp=1323.77 best_after=1323.77 acc=False ls_iters=  3 t_iter= 0.013s rem=None
# iter= 38 lvl=1 stag_before=  2 best_before=1323.77 pert=1357.96 imp=1322.24 best_after=1322.24 acc=True  ls_iters=  3 t_iter= 0.013s rem=None
# iter= 39 lvl=1 stag_before=  0 best_before=1322.24 pert=1459.94 imp=1326.76 best_after=1322.24 acc=False ls_iters=  3 t_iter= 0.020s rem=None
# iter= 40 lvl=1 stag_before=  1 best_before=1322.24 pert=1430.79 imp=1321.96 best_after=1321.96 acc=True  ls_iters=  3 t_iter= 0.016s rem=None
# iter= 41 lvl=1 stag_before=  0 best_before=1321.96 pert=1516.96 imp=1333.02 best_after=1321.96 acc=False ls_iters=  3 t_iter= 0.022s rem=None
# iter= 42 lvl=1 stag_before=  1 best_before=1321.96 pert=1506.88 imp=1321.96 best_after=1321.96 acc=False ls_iters=  3 t_iter= 0.018s rem=None
# iter= 43 lvl=1 stag_before=  2 best_before=1321.96 pert=1480.04 imp=1327.26 best_after=1321.96 acc=False ls_iters=  3 t_iter= 0.013s rem=None
# iter= 44 lvl=2 stag_before=  3 best_before=1321.96 pert=1500.40 imp=1327.26 best_after=1321.96 acc=False ls_iters=  3 t_iter= 0.025s rem=None
# iter= 45 lvl=2 stag_before=  4 best_before=1321.96 pert=1547.21 imp=1323.08 best_after=1321.96 acc=False ls_iters=  3 t_iter= 0.033s rem=None
# iter= 46 lvl=2 stag_before=  5 best_before=1321.96 pert=1551.94 imp=1389.27 best_after=1321.96 acc=False ls_iters=  3 t_iter= 0.024s rem=None
# iter= 47 lvl=3 stag_before=  6 best_before=1321.96 pert=1687.75 imp=1316.92 best_after=1316.92 acc=True  ls_iters=  3 t_iter= 0.041s rem=None
# iter= 48 lvl=1 stag_before=  0 best_before=1316.92 pert=1467.36 imp=1320.50 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.020s rem=None
# iter= 49 lvl=1 stag_before=  1 best_before=1316.92 pert=1396.03 imp=1316.92 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.014s rem=None
# iter= 50 lvl=1 stag_before=  2 best_before=1316.92 pert=1513.07 imp=1316.92 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter= 51 lvl=2 stag_before=  3 best_before=1316.92 pert=1504.21 imp=1330.28 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.028s rem=None
# iter= 52 lvl=2 stag_before=  4 best_before=1316.92 pert=1592.94 imp=1323.88 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.028s rem=None
# iter= 53 lvl=2 stag_before=  5 best_before=1316.92 pert=1567.56 imp=1321.07 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.025s rem=None
# iter= 54 lvl=3 stag_before=  6 best_before=1316.92 pert=1699.97 imp=1324.50 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.039s rem=None
# iter= 55 lvl=3 stag_before=  7 best_before=1316.92 pert=1748.91 imp=1326.97 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.037s rem=None
# iter= 56 lvl=3 stag_before=  8 best_before=1316.92 pert=1656.98 imp=1320.46 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.035s rem=None
# iter= 57 lvl=4 stag_before=  9 best_before=1316.92 pert=2051.09 imp=1346.19 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter= 58 lvl=4 stag_before= 10 best_before=1316.92 pert=1712.94 imp=1377.22 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter= 59 lvl=4 stag_before= 11 best_before=1316.92 pert=1599.37 imp=1372.79 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.022s rem=None
# iter= 60 lvl=5 stag_before= 12 best_before=1316.92 pert=1845.94 imp=1328.31 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.044s rem=None
# iter= 61 lvl=5 stag_before= 13 best_before=1316.92 pert=2101.36 imp=1329.51 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.053s rem=None
# iter= 62 lvl=5 stag_before= 14 best_before=1316.92 pert=1974.12 imp=1344.31 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.063s rem=None
# iter= 63 lvl=5 stag_before= 15 best_before=1316.92 pert=2041.50 imp=1382.32 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter= 64 lvl=5 stag_before= 16 best_before=1316.92 pert=1954.63 imp=1327.89 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter= 65 lvl=5 stag_before= 17 best_before=1316.92 pert=2049.48 imp=1321.35 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter= 66 lvl=5 stag_before= 18 best_before=1316.92 pert=2128.51 imp=1381.00 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter= 67 lvl=5 stag_before= 19 best_before=1316.92 pert=2034.76 imp=1333.25 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.059s rem=None
# iter= 68 lvl=5 stag_before= 20 best_before=1316.92 pert=2140.49 imp=1351.60 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.071s rem=None
# iter= 69 lvl=5 stag_before= 21 best_before=1316.92 pert=1952.44 imp=1338.28 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.071s rem=None
# iter= 70 lvl=5 stag_before= 22 best_before=1316.92 pert=1888.86 imp=1351.21 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.064s rem=None
# iter= 71 lvl=5 stag_before= 23 best_before=1316.92 pert=2088.38 imp=1328.34 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter= 72 lvl=5 stag_before= 24 best_before=1316.92 pert=2288.43 imp=1319.38 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter= 73 lvl=5 stag_before= 25 best_before=1316.92 pert=1846.84 imp=1352.85 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.078s rem=None
# iter= 74 lvl=5 stag_before= 26 best_before=1316.92 pert=1992.17 imp=1322.22 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.027s rem=None
# iter= 75 lvl=5 stag_before= 27 best_before=1316.92 pert=1978.54 imp=1317.92 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter= 76 lvl=5 stag_before= 28 best_before=1316.92 pert=2120.41 imp=1317.41 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.039s rem=None
# iter= 77 lvl=5 stag_before= 29 best_before=1316.92 pert=2228.19 imp=1320.97 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.066s rem=None
# iter= 78 lvl=5 stag_before= 30 best_before=1316.92 pert=2027.12 imp=1364.49 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.070s rem=None
# iter= 79 lvl=5 stag_before= 31 best_before=1316.92 pert=1992.19 imp=1401.19 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.087s rem=None
# iter= 80 lvl=5 stag_before= 32 best_before=1316.92 pert=2114.98 imp=1386.64 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter= 81 lvl=5 stag_before= 33 best_before=1316.92 pert=1906.24 imp=1320.52 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.042s rem=None
# iter= 82 lvl=5 stag_before= 34 best_before=1316.92 pert=2008.11 imp=1330.14 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.053s rem=None
# iter= 83 lvl=5 stag_before= 35 best_before=1316.92 pert=2218.29 imp=1334.79 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter= 84 lvl=5 stag_before= 36 best_before=1316.92 pert=2082.32 imp=1334.62 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.082s rem=None
# iter= 85 lvl=5 stag_before= 37 best_before=1316.92 pert=1916.86 imp=1377.91 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter= 86 lvl=5 stag_before= 38 best_before=1316.92 pert=1858.32 imp=1341.59 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter= 87 lvl=5 stag_before= 39 best_before=1316.92 pert=1853.01 imp=1333.52 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.066s rem=None
# iter= 88 lvl=5 stag_before= 40 best_before=1316.92 pert=1883.40 imp=1323.05 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter= 89 lvl=5 stag_before= 41 best_before=1316.92 pert=2199.34 imp=1350.59 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.072s rem=None
# iter= 90 lvl=5 stag_before= 42 best_before=1316.92 pert=1803.01 imp=1324.98 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.043s rem=None
# iter= 91 lvl=5 stag_before= 43 best_before=1316.92 pert=2166.60 imp=1329.93 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.037s rem=None
# iter= 92 lvl=5 stag_before= 44 best_before=1316.92 pert=2036.15 imp=1337.44 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.053s rem=None
# iter= 93 lvl=5 stag_before= 45 best_before=1316.92 pert=1863.87 imp=1326.10 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter= 94 lvl=5 stag_before= 46 best_before=1316.92 pert=1982.32 imp=1333.74 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.046s rem=None
# iter= 95 lvl=5 stag_before= 47 best_before=1316.92 pert=2065.20 imp=1327.52 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.047s rem=None
# iter= 96 lvl=5 stag_before= 48 best_before=1316.92 pert=2008.19 imp=1324.55 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.040s rem=None
# iter= 97 lvl=5 stag_before= 49 best_before=1316.92 pert=2021.93 imp=1350.10 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.073s rem=None
# iter= 98 lvl=5 stag_before= 50 best_before=1316.92 pert=2100.33 imp=1325.45 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter= 99 lvl=5 stag_before= 51 best_before=1316.92 pert=1885.32 imp=1339.55 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.043s rem=None
# iter=100 lvl=5 stag_before= 52 best_before=1316.92 pert=1954.62 imp=1335.37 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.057s rem=None
# iter=101 lvl=5 stag_before= 53 best_before=1316.92 pert=2286.37 imp=1343.61 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.070s rem=None
# iter=102 lvl=5 stag_before= 54 best_before=1316.92 pert=1721.66 imp=1374.74 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.024s rem=None
# iter=103 lvl=5 stag_before= 55 best_before=1316.92 pert=1996.23 imp=1387.41 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.040s rem=None
# iter=104 lvl=5 stag_before= 56 best_before=1316.92 pert=1871.69 imp=1332.84 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=105 lvl=5 stag_before= 57 best_before=1316.92 pert=1930.87 imp=1324.02 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter=106 lvl=5 stag_before= 58 best_before=1316.92 pert=1776.17 imp=1326.92 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.040s rem=None
# iter=107 lvl=5 stag_before= 59 best_before=1316.92 pert=2009.73 imp=1371.74 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.046s rem=None
# iter=108 lvl=5 stag_before= 60 best_before=1316.92 pert=2056.82 imp=1326.17 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.074s rem=None
# iter=109 lvl=5 stag_before= 61 best_before=1316.92 pert=2088.66 imp=1326.93 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.058s rem=None
# iter=110 lvl=5 stag_before= 62 best_before=1316.92 pert=2120.93 imp=1318.20 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter=111 lvl=5 stag_before= 63 best_before=1316.92 pert=1975.28 imp=1326.80 best_after=1316.92 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter=112 lvl=5 stag_before= 64 best_before=1316.92 pert=1926.51 imp=1315.98 best_after=1315.98 acc=True  ls_iters=  3 t_iter= 0.049s rem=None
# iter=113 lvl=1 stag_before=  0 best_before=1315.98 pert=1439.76 imp=1320.05 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.015s rem=None
# iter=114 lvl=1 stag_before=  1 best_before=1315.98 pert=1534.73 imp=1316.92 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.028s rem=None
# iter=115 lvl=1 stag_before=  2 best_before=1315.98 pert=1505.73 imp=1325.97 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.031s rem=None
# iter=116 lvl=2 stag_before=  3 best_before=1315.98 pert=1611.20 imp=1319.85 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter=117 lvl=2 stag_before=  4 best_before=1315.98 pert=1659.33 imp=1326.18 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.037s rem=None
# iter=118 lvl=2 stag_before=  5 best_before=1315.98 pert=1644.41 imp=1319.43 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.029s rem=None
# iter=119 lvl=3 stag_before=  6 best_before=1315.98 pert=1819.70 imp=1329.79 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter=120 lvl=3 stag_before=  7 best_before=1315.98 pert=1569.19 imp=1327.46 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.035s rem=None
# iter=121 lvl=3 stag_before=  8 best_before=1315.98 pert=1672.76 imp=1398.02 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter=122 lvl=4 stag_before=  9 best_before=1315.98 pert=1758.13 imp=1321.86 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.030s rem=None
# iter=123 lvl=4 stag_before= 10 best_before=1315.98 pert=1800.07 imp=1318.63 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.044s rem=None
# iter=124 lvl=4 stag_before= 11 best_before=1315.98 pert=1567.03 imp=1317.64 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.017s rem=None
# iter=125 lvl=5 stag_before= 12 best_before=1315.98 pert=1814.56 imp=1377.84 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.038s rem=None
# iter=126 lvl=5 stag_before= 13 best_before=1315.98 pert=1785.68 imp=1337.20 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter=127 lvl=5 stag_before= 14 best_before=1315.98 pert=2108.94 imp=1372.56 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=128 lvl=5 stag_before= 15 best_before=1315.98 pert=2047.30 imp=1324.53 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.075s rem=None
# iter=129 lvl=5 stag_before= 16 best_before=1315.98 pert=2066.51 imp=1371.67 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.065s rem=None
# iter=130 lvl=5 stag_before= 17 best_before=1315.98 pert=1896.59 imp=1316.75 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.057s rem=None
# iter=131 lvl=5 stag_before= 18 best_before=1315.98 pert=1899.30 imp=1328.41 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.047s rem=None
# iter=132 lvl=5 stag_before= 19 best_before=1315.98 pert=2250.35 imp=1341.01 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.121s rem=None
# iter=133 lvl=5 stag_before= 20 best_before=1315.98 pert=1914.07 imp=1318.17 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.038s rem=None
# iter=134 lvl=5 stag_before= 21 best_before=1315.98 pert=2060.49 imp=1378.15 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.043s rem=None
# iter=135 lvl=5 stag_before= 22 best_before=1315.98 pert=1899.64 imp=1322.51 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.034s rem=None
# iter=136 lvl=5 stag_before= 23 best_before=1315.98 pert=1904.61 imp=1322.56 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter=137 lvl=5 stag_before= 24 best_before=1315.98 pert=1928.58 imp=1331.51 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.062s rem=None
# iter=138 lvl=5 stag_before= 25 best_before=1315.98 pert=1909.62 imp=1325.75 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.064s rem=None
# iter=139 lvl=5 stag_before= 26 best_before=1315.98 pert=1802.72 imp=1319.85 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=140 lvl=5 stag_before= 27 best_before=1315.98 pert=1919.98 imp=1367.45 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter=141 lvl=5 stag_before= 28 best_before=1315.98 pert=1779.22 imp=1375.10 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.026s rem=None
# iter=142 lvl=5 stag_before= 29 best_before=1315.98 pert=1985.39 imp=1326.99 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter=143 lvl=5 stag_before= 30 best_before=1315.98 pert=2091.04 imp=1333.49 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.060s rem=None
# iter=144 lvl=5 stag_before= 31 best_before=1315.98 pert=1841.21 imp=1338.71 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=145 lvl=5 stag_before= 32 best_before=1315.98 pert=2083.74 imp=1393.57 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.041s rem=None
# iter=146 lvl=5 stag_before= 33 best_before=1315.98 pert=1832.32 imp=1328.31 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.030s rem=None
# iter=147 lvl=5 stag_before= 34 best_before=1315.98 pert=2011.33 imp=1323.65 best_after=1315.98 acc=False ls_iters=  3 t_iter= 0.039s rem=None
# iter=148 lvl=5 stag_before= 35 best_before=1315.98 pert=1950.81 imp=1314.55 best_after=1314.55 acc=True  ls_iters=  3 t_iter= 0.030s rem=None
# iter=149 lvl=1 stag_before=  0 best_before=1314.55 pert=1461.87 imp=1314.55 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.018s rem=None
# iter=150 lvl=1 stag_before=  1 best_before=1314.55 pert=1469.04 imp=1316.33 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.021s rem=None
# iter=151 lvl=1 stag_before=  2 best_before=1314.55 pert=1427.41 imp=1319.51 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.017s rem=None
# iter=152 lvl=2 stag_before=  3 best_before=1314.55 pert=1490.55 imp=1316.33 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.022s rem=None
# iter=153 lvl=2 stag_before=  4 best_before=1314.55 pert=1628.70 imp=1319.94 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.040s rem=None
# iter=154 lvl=2 stag_before=  5 best_before=1314.55 pert=1597.85 imp=1324.84 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.024s rem=None
# iter=155 lvl=3 stag_before=  6 best_before=1314.55 pert=1690.14 imp=1315.42 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.028s rem=None
# iter=156 lvl=3 stag_before=  7 best_before=1314.55 pert=1842.14 imp=1341.17 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter=157 lvl=3 stag_before=  8 best_before=1314.55 pert=1677.73 imp=1331.66 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.028s rem=None
# iter=158 lvl=4 stag_before=  9 best_before=1314.55 pert=2137.93 imp=1322.40 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.068s rem=None
# iter=159 lvl=4 stag_before= 10 best_before=1314.55 pert=1884.14 imp=1324.98 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.046s rem=None
# iter=160 lvl=4 stag_before= 11 best_before=1314.55 pert=1755.60 imp=1318.06 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.034s rem=None
# iter=161 lvl=5 stag_before= 12 best_before=1314.55 pert=1814.55 imp=1325.63 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=162 lvl=5 stag_before= 13 best_before=1314.55 pert=1975.48 imp=1314.94 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.042s rem=None
# iter=163 lvl=5 stag_before= 14 best_before=1314.55 pert=2332.36 imp=1345.93 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.127s rem=None
# iter=164 lvl=5 stag_before= 15 best_before=1314.55 pert=1981.01 imp=1340.11 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=165 lvl=5 stag_before= 16 best_before=1314.55 pert=2118.48 imp=1359.15 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=166 lvl=5 stag_before= 17 best_before=1314.55 pert=1893.54 imp=1323.29 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.032s rem=None
# iter=167 lvl=5 stag_before= 18 best_before=1314.55 pert=1853.71 imp=1346.33 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter=168 lvl=5 stag_before= 19 best_before=1314.55 pert=2008.64 imp=1344.18 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.095s rem=None
# iter=169 lvl=5 stag_before= 20 best_before=1314.55 pert=2078.45 imp=1323.55 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.031s rem=None
# iter=170 lvl=5 stag_before= 21 best_before=1314.55 pert=2029.17 imp=1372.17 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.066s rem=None
# iter=171 lvl=5 stag_before= 22 best_before=1314.55 pert=1988.12 imp=1385.05 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.033s rem=None
# iter=172 lvl=5 stag_before= 23 best_before=1314.55 pert=2078.30 imp=1317.36 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=173 lvl=5 stag_before= 24 best_before=1314.55 pert=1800.58 imp=1364.48 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.027s rem=None
# iter=174 lvl=5 stag_before= 25 best_before=1314.55 pert=2040.01 imp=1325.61 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.049s rem=None
# iter=175 lvl=5 stag_before= 26 best_before=1314.55 pert=1986.96 imp=1329.15 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter=176 lvl=5 stag_before= 27 best_before=1314.55 pert=1911.24 imp=1328.35 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.058s rem=None
# iter=177 lvl=5 stag_before= 28 best_before=1314.55 pert=2144.50 imp=1328.07 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=178 lvl=5 stag_before= 29 best_before=1314.55 pert=1992.46 imp=1322.32 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.034s rem=None
# iter=179 lvl=5 stag_before= 30 best_before=1314.55 pert=1815.30 imp=1328.44 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter=180 lvl=5 stag_before= 31 best_before=1314.55 pert=2041.17 imp=1333.69 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter=181 lvl=5 stag_before= 32 best_before=1314.55 pert=2007.75 imp=1321.62 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter=182 lvl=5 stag_before= 33 best_before=1314.55 pert=1888.94 imp=1394.20 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.049s rem=None
# iter=183 lvl=5 stag_before= 34 best_before=1314.55 pert=1841.34 imp=1341.16 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.060s rem=None
# iter=184 lvl=5 stag_before= 35 best_before=1314.55 pert=1736.12 imp=1331.93 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.033s rem=None
# iter=185 lvl=5 stag_before= 36 best_before=1314.55 pert=2005.81 imp=1341.04 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter=186 lvl=5 stag_before= 37 best_before=1314.55 pert=2017.12 imp=1343.07 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.047s rem=None
# iter=187 lvl=5 stag_before= 38 best_before=1314.55 pert=1958.39 imp=1317.81 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.044s rem=None
# iter=188 lvl=5 stag_before= 39 best_before=1314.55 pert=2325.00 imp=1330.83 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.070s rem=None
# iter=189 lvl=5 stag_before= 40 best_before=1314.55 pert=1781.19 imp=1324.70 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.033s rem=None
# iter=190 lvl=5 stag_before= 41 best_before=1314.55 pert=2167.68 imp=1357.44 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.084s rem=None
# iter=191 lvl=5 stag_before= 42 best_before=1314.55 pert=1928.99 imp=1331.07 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=192 lvl=5 stag_before= 43 best_before=1314.55 pert=1767.42 imp=1334.35 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter=193 lvl=5 stag_before= 44 best_before=1314.55 pert=1781.36 imp=1385.47 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter=194 lvl=5 stag_before= 45 best_before=1314.55 pert=2185.58 imp=1324.51 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.063s rem=None
# iter=195 lvl=5 stag_before= 46 best_before=1314.55 pert=2005.91 imp=1329.92 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.067s rem=None
# iter=196 lvl=5 stag_before= 47 best_before=1314.55 pert=2164.20 imp=1327.55 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.029s rem=None
# iter=197 lvl=5 stag_before= 48 best_before=1314.55 pert=2289.68 imp=1330.55 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=198 lvl=5 stag_before= 49 best_before=1314.55 pert=1916.72 imp=1314.62 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.031s rem=None
# iter=199 lvl=5 stag_before= 50 best_before=1314.55 pert=1935.89 imp=1321.21 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.059s rem=None
# iter=200 lvl=5 stag_before= 51 best_before=1314.55 pert=1904.16 imp=1334.85 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=201 lvl=5 stag_before= 52 best_before=1314.55 pert=2287.13 imp=1347.23 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.047s rem=None
# iter=202 lvl=5 stag_before= 53 best_before=1314.55 pert=1745.88 imp=1338.08 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=203 lvl=5 stag_before= 54 best_before=1314.55 pert=2102.39 imp=1341.20 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.094s rem=None
# iter=204 lvl=5 stag_before= 55 best_before=1314.55 pert=1729.28 imp=1318.10 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.034s rem=None
# iter=205 lvl=5 stag_before= 56 best_before=1314.55 pert=2030.34 imp=1326.65 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.057s rem=None
# iter=206 lvl=5 stag_before= 57 best_before=1314.55 pert=1915.96 imp=1331.33 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=207 lvl=5 stag_before= 58 best_before=1314.55 pert=1877.58 imp=1328.38 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.037s rem=None
# iter=208 lvl=5 stag_before= 59 best_before=1314.55 pert=2150.87 imp=1339.99 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.073s rem=None
# iter=209 lvl=5 stag_before= 60 best_before=1314.55 pert=1953.54 imp=1314.55 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.029s rem=None
# iter=210 lvl=5 stag_before= 61 best_before=1314.55 pert=2002.00 imp=1333.87 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.043s rem=None
# iter=211 lvl=5 stag_before= 62 best_before=1314.55 pert=2008.90 imp=1330.21 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.073s rem=None
# iter=212 lvl=5 stag_before= 63 best_before=1314.55 pert=1984.82 imp=1327.32 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.047s rem=None
# iter=213 lvl=5 stag_before= 64 best_before=1314.55 pert=2033.21 imp=1323.52 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.059s rem=None
# iter=214 lvl=5 stag_before= 65 best_before=1314.55 pert=2083.04 imp=1328.84 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.053s rem=None
# iter=215 lvl=5 stag_before= 66 best_before=1314.55 pert=2111.68 imp=1327.60 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.049s rem=None
# iter=216 lvl=5 stag_before= 67 best_before=1314.55 pert=2099.82 imp=1335.51 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.062s rem=None
# iter=217 lvl=5 stag_before= 68 best_before=1314.55 pert=1813.42 imp=1330.20 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.046s rem=None
# iter=218 lvl=5 stag_before= 69 best_before=1314.55 pert=1687.26 imp=1320.87 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=219 lvl=5 stag_before= 70 best_before=1314.55 pert=2008.07 imp=1329.35 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.061s rem=None
# iter=220 lvl=5 stag_before= 71 best_before=1314.55 pert=1631.50 imp=1317.29 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.033s rem=None
# iter=221 lvl=5 stag_before= 72 best_before=1314.55 pert=1803.00 imp=1326.40 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.049s rem=None
# iter=222 lvl=5 stag_before= 73 best_before=1314.55 pert=1923.24 imp=1322.24 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.060s rem=None
# iter=223 lvl=5 stag_before= 74 best_before=1314.55 pert=1976.84 imp=1329.71 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.049s rem=None
# iter=224 lvl=5 stag_before= 75 best_before=1314.55 pert=1903.56 imp=1337.18 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter=225 lvl=5 stag_before= 76 best_before=1314.55 pert=2005.01 imp=1334.77 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.069s rem=None
# iter=226 lvl=5 stag_before= 77 best_before=1314.55 pert=1979.40 imp=1319.84 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.061s rem=None
# iter=227 lvl=5 stag_before= 78 best_before=1314.55 pert=1925.90 imp=1321.13 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.038s rem=None
# iter=228 lvl=5 stag_before= 79 best_before=1314.55 pert=2068.52 imp=1319.93 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.053s rem=None
# iter=229 lvl=5 stag_before= 80 best_before=1314.55 pert=1816.63 imp=1333.17 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter=230 lvl=5 stag_before= 81 best_before=1314.55 pert=2126.36 imp=1332.04 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.053s rem=None
# iter=231 lvl=5 stag_before= 82 best_before=1314.55 pert=2009.53 imp=1326.59 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.068s rem=None
# iter=232 lvl=5 stag_before= 83 best_before=1314.55 pert=1962.31 imp=1346.83 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.066s rem=None
# iter=233 lvl=5 stag_before= 84 best_before=1314.55 pert=1962.13 imp=1326.95 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.038s rem=None
# iter=234 lvl=5 stag_before= 85 best_before=1314.55 pert=1982.03 imp=1327.21 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=235 lvl=5 stag_before= 86 best_before=1314.55 pert=1883.60 imp=1322.19 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.035s rem=None
# iter=236 lvl=5 stag_before= 87 best_before=1314.55 pert=2099.43 imp=1336.11 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.074s rem=None
# iter=237 lvl=5 stag_before= 88 best_before=1314.55 pert=1859.39 imp=1319.94 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.038s rem=None
# iter=238 lvl=5 stag_before= 89 best_before=1314.55 pert=1948.68 imp=1356.19 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.083s rem=None
# iter=239 lvl=5 stag_before= 90 best_before=1314.55 pert=1869.59 imp=1333.59 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.068s rem=None
# iter=240 lvl=5 stag_before= 91 best_before=1314.55 pert=2079.27 imp=1322.80 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.041s rem=None
# iter=241 lvl=5 stag_before= 92 best_before=1314.55 pert=2103.61 imp=1346.83 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.060s rem=None
# iter=242 lvl=5 stag_before= 93 best_before=1314.55 pert=1923.77 imp=1325.52 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.043s rem=None
# iter=243 lvl=5 stag_before= 94 best_before=1314.55 pert=1938.23 imp=1329.02 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.064s rem=None
# iter=244 lvl=5 stag_before= 95 best_before=1314.55 pert=1877.13 imp=1320.07 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.036s rem=None
# iter=245 lvl=5 stag_before= 96 best_before=1314.55 pert=1898.69 imp=1318.54 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.038s rem=None
# iter=246 lvl=5 stag_before= 97 best_before=1314.55 pert=2021.25 imp=1344.33 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=247 lvl=5 stag_before= 98 best_before=1314.55 pert=1887.76 imp=1322.89 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.063s rem=None
# iter=248 lvl=5 stag_before= 99 best_before=1314.55 pert=1866.29 imp=1345.56 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter=249 lvl=5 stag_before=100 best_before=1314.55 pert=1875.92 imp=1330.64 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.032s rem=None
# iter=250 lvl=5 stag_before=101 best_before=1314.55 pert=2091.53 imp=1329.73 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=251 lvl=5 stag_before=102 best_before=1314.55 pert=1969.75 imp=1323.55 best_after=1314.55 acc=False ls_iters=  3 t_iter= 0.058s rem=None
# iter=252 lvl=5 stag_before=103 best_before=1314.55 pert=1770.19 imp=1314.54 best_after=1314.54 acc=True  ls_iters=  3 t_iter= 0.045s rem=None
# iter=253 lvl=1 stag_before=  0 best_before=1314.54 pert=1403.82 imp=1314.54 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.011s rem=None
# iter=254 lvl=1 stag_before=  1 best_before=1314.54 pert=1420.83 imp=1318.12 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.013s rem=None
# iter=255 lvl=1 stag_before=  2 best_before=1314.54 pert=1463.69 imp=1314.54 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.019s rem=None
# iter=256 lvl=2 stag_before=  3 best_before=1314.54 pert=1619.06 imp=1314.54 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.060s rem=None
# iter=257 lvl=2 stag_before=  4 best_before=1314.54 pert=1658.64 imp=1334.22 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.033s rem=None
# iter=258 lvl=2 stag_before=  5 best_before=1314.54 pert=1597.47 imp=1320.78 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.022s rem=None
# iter=259 lvl=3 stag_before=  6 best_before=1314.54 pert=1740.19 imp=1327.36 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.037s rem=None
# iter=260 lvl=3 stag_before=  7 best_before=1314.54 pert=1797.61 imp=1326.96 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.061s rem=None
# iter=261 lvl=3 stag_before=  8 best_before=1314.54 pert=1812.11 imp=1325.09 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter=262 lvl=4 stag_before=  9 best_before=1314.54 pert=1772.14 imp=1341.95 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter=263 lvl=4 stag_before= 10 best_before=1314.54 pert=1913.81 imp=1325.09 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=264 lvl=4 stag_before= 11 best_before=1314.54 pert=1810.64 imp=1318.96 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=265 lvl=5 stag_before= 12 best_before=1314.54 pert=2036.87 imp=1328.02 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=266 lvl=5 stag_before= 13 best_before=1314.54 pert=2029.41 imp=1319.93 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.043s rem=None
# iter=267 lvl=5 stag_before= 14 best_before=1314.54 pert=1895.93 imp=1329.90 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter=268 lvl=5 stag_before= 15 best_before=1314.54 pert=2023.37 imp=1335.96 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.049s rem=None
# iter=269 lvl=5 stag_before= 16 best_before=1314.54 pert=2163.36 imp=1331.31 best_after=1314.54 acc=False ls_iters=  3 t_iter= 0.075s rem=None
# iter=270 lvl=5 stag_before= 17 best_before=1314.54 pert=1828.20 imp=1310.66 best_after=1310.66 acc=True  ls_iters=  3 t_iter= 0.028s rem=None
# iter=271 lvl=1 stag_before=  0 best_before=1310.66 pert=1458.11 imp=1317.65 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.026s rem=None
# iter=272 lvl=1 stag_before=  1 best_before=1310.66 pert=1418.90 imp=1315.28 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.021s rem=None
# iter=273 lvl=1 stag_before=  2 best_before=1310.66 pert=1381.29 imp=1310.66 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.017s rem=None
# iter=274 lvl=2 stag_before=  3 best_before=1310.66 pert=1639.76 imp=1322.16 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.026s rem=None
# iter=275 lvl=2 stag_before=  4 best_before=1310.66 pert=1631.26 imp=1329.73 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.041s rem=None
# iter=276 lvl=2 stag_before=  5 best_before=1310.66 pert=1545.15 imp=1315.63 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.030s rem=None
# iter=277 lvl=3 stag_before=  6 best_before=1310.66 pert=1754.92 imp=1317.95 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.042s rem=None
# iter=278 lvl=3 stag_before=  7 best_before=1310.66 pert=1756.35 imp=1330.41 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.055s rem=None
# iter=279 lvl=3 stag_before=  8 best_before=1310.66 pert=1933.37 imp=1319.89 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.042s rem=None
# iter=280 lvl=4 stag_before=  9 best_before=1310.66 pert=1952.40 imp=1311.60 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter=281 lvl=4 stag_before= 10 best_before=1310.66 pert=1683.31 imp=1312.03 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.044s rem=None
# iter=282 lvl=4 stag_before= 11 best_before=1310.66 pert=1578.46 imp=1316.26 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.029s rem=None
# iter=283 lvl=5 stag_before= 12 best_before=1310.66 pert=1879.68 imp=1316.54 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=284 lvl=5 stag_before= 13 best_before=1310.66 pert=1937.85 imp=1325.50 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.039s rem=None
# iter=285 lvl=5 stag_before= 14 best_before=1310.66 pert=2039.42 imp=1314.88 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.070s rem=None
# iter=286 lvl=5 stag_before= 15 best_before=1310.66 pert=1942.64 imp=1341.37 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter=287 lvl=5 stag_before= 16 best_before=1310.66 pert=2259.67 imp=1315.67 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.050s rem=None
# iter=288 lvl=5 stag_before= 17 best_before=1310.66 pert=1827.03 imp=1319.29 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.054s rem=None
# iter=289 lvl=5 stag_before= 18 best_before=1310.66 pert=2012.54 imp=1339.06 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.052s rem=None
# iter=290 lvl=5 stag_before= 19 best_before=1310.66 pert=1993.52 imp=1324.28 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.056s rem=None
# iter=291 lvl=5 stag_before= 20 best_before=1310.66 pert=1827.69 imp=1321.64 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.033s rem=None
# iter=292 lvl=5 stag_before= 21 best_before=1310.66 pert=2070.08 imp=1316.08 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.049s rem=None
# iter=293 lvl=5 stag_before= 22 best_before=1310.66 pert=2001.90 imp=1323.48 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.063s rem=None
# iter=294 lvl=5 stag_before= 23 best_before=1310.66 pert=1994.38 imp=1388.73 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.060s rem=None
# iter=295 lvl=5 stag_before= 24 best_before=1310.66 pert=1708.99 imp=1316.81 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.045s rem=None
# iter=296 lvl=5 stag_before= 25 best_before=1310.66 pert=1861.96 imp=1409.87 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.048s rem=None
# iter=297 lvl=5 stag_before= 26 best_before=1310.66 pert=2181.32 imp=1323.05 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.041s rem=None
# iter=298 lvl=5 stag_before= 27 best_before=1310.66 pert=2127.23 imp=1339.08 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.051s rem=None
# iter=299 lvl=5 stag_before= 28 best_before=1310.66 pert=2198.84 imp=1319.59 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.067s rem=None
# iter=300 lvl=5 stag_before= 29 best_before=1310.66 pert=2302.21 imp=1321.10 best_after=1310.66 acc=False ls_iters=  3 t_iter= 0.034s rem=None
# === AILS END === best_cost=1310.6593, total_time=13.542s

# %% [markdown]
# # Testing

# %%
def benchmark_lovebird(
    N=10,
    budget_s=None,
    # argumen problem di-pass lewat kwargs:
    **problem_kwargs
):
    """
    Jalankan iterated_lovebird dan adaptive_iterated_lovebird masing2 N kali,
    simpan best_cost dan runtime, lalu balikin DataFrame + plot boxplot.
    """
    results = []

    for run_id in range(N):
        seed = None  # supaya replikabel

        # --- ILS biasa ---
        t0 = time.perf_counter()
        _, cost_ils, _hist_ils = iterated_lovebird(
            max_iter=600, local_gen=3,
            init_mutations=30,
            budget_s=budget_s,
            seed=seed,
            **problem_kwargs
        )
        t1 = time.perf_counter()
        time_ils = t1 - t0

        results.append({
            "run": run_id,
            "algo": "ILS",
            "cost": float(cost_ils),
            "time_sec": float(time_ils),
        })

        # --- adaptive ILS ---
        t0 = time.perf_counter()
        _, cost_hils, _hist_hils = adaptive_iterated_lovebird(
            max_iter=600, local_gen=3,
            patience=2,
            init_mutations=30,
            budget_s=budget_s,
            seed=seed,
            **problem_kwargs
        )
        t1 = time.perf_counter()
        time_hils = t1 - t0

        results.append({
            "run": run_id,
            "algo": "AILS",
            "cost": float(cost_hils),
            "time_sec": float(time_hils),
        })

    df = pd.DataFrame(results)
    return df


def plot_boxplots(df: pd.DataFrame):
    """
    Bikin dua boxplot:
    - distribusi cost
    - distribusi runtime (detik)
    """
    # --- Boxplot cost ---
    plt.figure()
    df.boxplot(column="cost", by="algo")
    plt.title("Distribusi Cost per Algoritma")
    plt.suptitle("")  # hilangkan judul default pandas
    plt.xlabel("Algoritma")
    plt.ylabel("Cost")
    plt.grid(True, axis="y", linestyle="--", alpha=0.4)

    # --- Boxplot waktu ---
    plt.figure()
    df.boxplot(column="time_sec", by="algo")
    plt.title("Distribusi Runtime per Algoritma")
    plt.suptitle("")
    plt.xlabel("Algoritma")
    plt.ylabel("Waktu (detik)")
    plt.grid(True, axis="y", linestyle="--", alpha=0.4)

    plt.show()


def print_stats(df: pd.DataFrame):
    """
    Cetak ringkasan statistik cost & runtime (mean, std, median, min, max)
    mirip yang kamu tulis sebelumnya.
    """
    for algo in sorted(df["algo"].unique()):
        sub = df[df["algo"] == algo]
        cost = sub["cost"]
        t = sub["time_sec"]

        cost_mean = cost.mean()
        cost_std  = cost.std(ddof=1)
        cost_med  = cost.median()
        cost_min  = cost.min()
        cost_max  = cost.max()

        t_mean = t.mean()
        t_std  = t.std(ddof=1)
        t_med  = t.median()
        t_min  = t.min()
        t_max  = t.max()

        print(f"{algo:<9}: cost {cost_mean:.2f}±{cost_std:.2f} "
              f"(med {cost_med:.2f}) [{cost_min:.2f}, {cost_max:.2f}] | "
              f"time {t_mean:.2f}±{t_std:.2f}s "
              f"(med {t_med:.2f}) [{t_min:.2f}, {t_max:.2f}]")

# %%
df = benchmark_lovebird(
    N=20,
    budget_s=None,      # atau None / nilai lain sesuai eksperimenmu
    labels=labels, nodes=nodes,
)

print_stats(df)     # ringkasan numerik
plot_boxplots(df)   # tampilkan boxplot
# Out:
# AILS     : cost 1305.72±0.12 (med 1305.65) [1305.65, 1306.05] | time 14.87±0.78s (med 14.95) [13.25, 16.19]
# ILS      : cost 1309.08±2.90 (med 1307.68) [1306.05, 1315.28] | time 12.10±0.45s (med 12.12) [11.33, 13.13]
